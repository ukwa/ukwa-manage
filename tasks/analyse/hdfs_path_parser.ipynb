# %% [markdown]
# This notebook provides an environment for testing changes to the HDFS path parser we use to classify and track the contents of HDFS.
#
# To see how things will change, we can compare what we get against the current production results: http://intranet.wa.bl.uk/ukwa-reports/reports/hdfs/
#
# First we need to get an up-to-date copy of the full listing of files on HDFS. These are generated daily and placed on HDFS.

# %%
# !ls -lh /mnt/gluster/ingest/task-state/hdfs/current/
# Out:
# total 2.0G
# -rw-r--r--. 1 root root 527M Jul 17 01:00 current-hdfs-all-files-list.csv
# -rw-r--r--. 1 root root  37M Jul 17 01:57 current-hdfs-all-files-list.csv.gz
# -rw-r--r--. 1 root root 526M Jul 16 00:56 current-hdfs-all-files-list.csv.old
# -rw-r--r--. 1 root root 930M Jul 17 01:28 current-hdfs-parsed-paths.csv

# %%
# This cell is tagged `parameters` (use View > Cell Toolbar > Tags to modify)
file_list_csv = '/mnt/gluster/ingest/task-state/hdfs/current/current-hdfs-all-files-list.csv'
#file_list_csv = 'test/2019-07-04-hdfs-all-files-list_random-sample.csv'
parsed_files_csv = 'test/hdfs-parsed-paths.csv'

# %% [markdown]
# Now we can run the path parser on it:

# %%
import os
import sys
import re
import csv
import enum
import datetime
import logging

# Set up a logger to give some feedback:
logger = logging.getLogger()
    
# Expected headers for the raw HDFS file list CSV, see ListAllFilesOnHDFSToLocalFile
file_list_headers = ['permissions', 'number_of_replicas', 'userid', 'groupid', 'filesize', 'modified_at', 'filename']


class HdfsPathParser(object):
    """
    This class takes a HDFS file path and determines what, if any, crawl it belongs to, etc.
    """

    @staticmethod
    def field_names():
        """This returns the extended set of field names that this class derives from the basic listing."""
        return ['recognised', 'collection', 'stream','job', 'layout', 'kind', 'permissions', 'number_of_replicas', 'user_id', 'group_id', 'file_size', 'modified_at', 'timestamp', 'file_path', 'file_name', 'file_ext']

    def __init__(self, item):
        """
        Given a string containing the absolute HDFS file path, parse it to work our what kind of thing it is.

        Determines crawl job, launch, kind of file, etc.

        For WCT-era selective content, the job is the Target ID and the launch is the Instance ID.

        :param file_path:
        """

        # Perform basic processing:
        # ------------------------------------------------
        # To be captured later
        self.recognised = False
        self.collection = None
        self.stream = None
        self.layout = None
        self.job = None
        self.kind = 'unknown'
        # From the item listing:
        self.permissions = item['permissions']
        self.number_of_replicas = item['number_of_replicas']
        self.user_id = item['userid']
        self.group_id = item['groupid']
        self.file_size = item['filesize']
        self.modified_at = item['modified_at']
        self.file_path = item['filename']
        # Derived:
        self.file_name = os.path.basename(self.file_path)
        first_dot_at = self.file_name.find('.')
        if first_dot_at != -1:
            self.file_ext = self.file_name[first_dot_at:]
        else:
            self.file_ext = None
        self.timestamp_datetime = datetime.datetime.strptime(item['modified_at'], "%Y-%m-%dT%H:%M:%S")
        self.timestamp = self.timestamp_datetime.isoformat()
        self.launch_datetime = None

        # Look for different filename patterns:
        # ------------------------------------------------
        self.analyse_file_path()

        # Now Add data based on file kind and file name...
        # ------------------------------------------------

        # Distinguish 'bad' crawl files, e.g. warc.gz.open files that are down as warcs
        if self.kind == 'warcs':
            if not self.file_name.endswith(".warc.gz"):
                # The older selective crawls allowed CDX files alongside the WARCs:
                if self.collection == 'selective' and self.file_name.endswith(".warc.cdx"):
                    self.kind = 'cdx'
                else:
                    self.kind = 'warcs-invalid'
            else:
                # Attempt to parse file timestamp out of filename,
                # Store ISO formatted date in self.timestamp, datetime object in self.timestamp_datetime
                mwarc = re.search('^.*-([12][0-9]{16})-.*\.warc\.gz$', self.file_name)
                if mwarc:
                    self.timestamp_datetime = datetime.datetime.strptime(mwarc.group(1), "%Y%m%d%H%M%S%f")
                    self.timestamp = self.timestamp_datetime.isoformat()
                else:
                    if self.stream and self.launch_datetime:
                        # fall back on launch datetime:
                        self.timestamp_datetime = self.launch_datetime
                        self.timestamp = self.timestamp_datetime.isoformat()

        # Distinguish crawl logs from other logs...
        if self.kind == 'logs':
            if self.file_name.startswith("crawl.log"):
                self.kind = 'crawl-logs'

    def analyse_file_path(self):
        """
        This function analyses the file path to classify the item.
        """
        
        #
        # Selective era layout /data/<target-id>/<instance-id>/<kind>
        #
        if re.search('^/data/', self.file_path ):
            self.layout = 'wct'
            self.collection = 'selective'
            self.stream = CrawlStream.selective
            mby  = re.search('^/data/([0-9]+)/([0-9]+)/(DLX/|Logs/|WARCS/|)([^\/]+)$', self.file_path)
            if mby:
                self.recognised = True
                # In this case the job is the Target ID and the launch is the Instance ID:
                (self.job, self.launch, self.kind, self.file_name) = mby.groups()
                self.kind = self.kind.lower().strip('/')
                if self.kind == '':
                    self.kind = 'unknown'
                self.launch_datetime = None
                return
                
        # 
        # First NPLD era file layout /heritrix/output/(warcs|viral|logs)/<job>...
        #
        if re.search('^/heritrix/output/(warcs|viral|logs)/.*', self.file_path ):
            self.layout = 'npld-2013'
            self.collection = 'npld'
            # Original domain-crawl layout: kind/job (need to look for this first)
            mdc  = re.search('^/heritrix/output/(warcs|viral|logs)/(dc|crawl)[0-3]\-([0-9]{8}|[0-9]{14})/([^\/]+)$', self.file_path)
            # original frequent crawl layout: kind/job/launch-id
            mfc  = re.search('^/heritrix/output/(warcs|viral|logs)/([a-z\-0-9]+)[-/]([0-9]{12,14})/([^\/]+)$', self.file_path)
            if mdc:
                self.recognised = True
                self.stream = CrawlStream.domain
                (self.kind, self.job, self.launch, self.file_name) = mdc.groups()
                self.job = 'dc%s' % self.launch[0:4] # Overriding old job name.
                # Cope with variation in folder naming - all DC crawlers run as a single launch on the same day:
                if len(self.launch) > 8:
                    self.launch = self.launch[0:8]
                self.launch_datetime = datetime.datetime.strptime(self.launch, "%Y%m%d")
                return
            elif mfc:
                self.recognised = True
                self.stream = CrawlStream.frequent
                (self.kind, self.job, self.launch, self.file_name) = mfc.groups()
                self.launch_datetime = datetime.datetime.strptime(self.launch, "%Y%m%d%H%M%S")
                return

        # 
        # Second NPLD era file layout /heritrix/output/<job>/<launch>(warcs|viral|logs)/...
        #
        if re.search('^/heritrix/output/(dc2.+|frequent.*)/.*', self.file_path ):
            self.layout = 'npld-2018'
            self.collection = 'npld'
            # 2019 frequent-crawl layout: job/launch-id/kind (same as DC now?
            mfc2 = re.search('^/heritrix/output/([a-z\-0-9]+)/([0-9]{12,14})[^/]*/(warcs|viral|logs)/([^\/]+)$', self.file_path)
            if mfc2:
                self.recognised = True
                (self.job, self.launch, self.kind, self.file_name) = mfc2.groups()
                # Recognise domain crawls:
                if self.job.startswith('dc2'):
                    self.stream = CrawlStream.domain
                else:
                    self.stream = CrawlStream.frequent
                # Parse a launch datetime
                self.launch_datetime = datetime.datetime.strptime(self.launch, "%Y%m%d%H%M%S")
                return
                
        # 
        # Files that should be considered important data and eventually archived.
        #
        if self.file_path.startswith('/1_data/'):
            mf = re.search('^/1_data/npld/([a-z\-_0-9]+)/([a-z\-_0-9]+)/(warcs|viral|logs)/([^\/]+)$', self.file_path)
            if mf:
                self.recognised = True
                (self.stream, self.job, self.kind, self.file_name) = mf.groups()
                self.layout = 'npld-2018-project'
                self.collection = 'npld'
                return
            
        # 
        # Files stored but intended for deletion.
        #
        if self.file_path.startswith('/_to_be_deleted/'):
            self.recognised = True
            self.kind = 'to-be-deleted'
            self.file_name = os.path.basename(self.file_path)
            return
            
        #
        # If un-matched, default to classifying by top-level folder.
        #
        self.collection = self.file_path.split(os.path.sep)[1]
        self.file_name = os.path.basename(self.file_path)
        

    def to_dict(self):
        d = dict()
        for f in self.field_names():
            d[f] = str(getattr(self,f,""))
        return d


class CrawlStream(enum.Enum):
    """
    An enumeration of the different crawl streams.
    """

    selective = 1
    """'selective' is permissions-based collection. e.g. Pre-NPLD collections."""

    frequent = 2
    """ 'frequent' covers NPLD crawls of curated sites."""

    domain = 3
    """ 'domain' refers to NPLD domain crawls."""

    def __str__(self):
        return self.name

# Now parse the input and classify the entries:
lines = 0
with open(parsed_files_csv, 'w') as fout:
    # Set up output file:
    writer = csv.DictWriter(fout, fieldnames=HdfsPathParser.field_names())
    writer.writeheader()
    with open(file_list_csv, 'r') as fin:
        reader = csv.DictReader(fin, fieldnames=file_list_headers)
        for item in reader:
            # Skip the first line:
            if item['filesize'] == 'filesize':
                continue
            # Output the enriched version:
            p = HdfsPathParser(item)
            writer.writerow(p.to_dict())
            lines += 1
            if lines%500000 == 0:
                logger.warning("Processed %i lines..." % lines)

logger.warning("Done. Processed a total of %i lines." % lines)
# Out:
# Processed 500000 lines...
# Processed 1000000 lines...
# Processed 1500000 lines...
# Processed 2000000 lines...
# Processed 2500000 lines...
# Processed 3000000 lines...
# Processed 3500000 lines...
# Done. Processed a total of 3771125 lines.

# %%
import pandas as pd
from data_formatters import humanbytes

# Enable inline plots
# %matplotlib inline

# Do not truncate file path display:
pd.set_option('display.max_colwidth', -1)

# Show more rows
pd.options.display.max_rows = 4000

# Load the data:
df = pd.read_csv(parsed_files_csv)

# Interpret modified_at and timestamp as a datetimes:
df.timestamp = pd.to_datetime(df.timestamp)

# Ignore the to-be-deleted data:
df = df.loc[df['kind'] != 'to-be-deleted']

# Show us the data:
df.head()
# Out:
#    recognised  collection stream   job layout     kind permissions  \
# 0  False       0_original  None   None  None   unknown  -rw-r--r--
# 1  False       0_original  None   None  None   unknown  -rw-r--r--
# 2  False       0_original  None   None  None   unknown  -rw-r--r--
# 3  False       0_original  None   None  None   unknown  -rw-r--r--
# 4  False       0_original  None   None  None   unknown  -rw-r--r--
#
#    number_of_replicas user_id    group_id  file_size          modified_at  \
# 0  3                   hdfs    supergroup  206979     2016-05-24T10:55:00
# 1  3                   hdfs    supergroup  259004     2016-05-24T10:55:00
# 2  3                   hdfs    supergroup  137950     2016-05-24T10:56:00
# 3  3                   hdfs    supergroup  157173     2016-05-24T10:56:00
# 4  3                   hdfs    supergroup  121905     2016-05-24T10:56:00
#
#             timestamp  \
# 0 2016-05-24 10:55:00
# 1 2016-05-24 10:55:00
# 2 2016-05-24 10:56:00
# 3 2016-05-24 10:56:00
# 4 2016-05-24 10:56:00
#
#                                                         file_path  \
# 0  /0_original/fc/crawler03/heritrix/output/images/1365759028.jpg
# 1  /0_original/fc/crawler03/heritrix/output/images/1365759053.jpg
# 2  /0_original/fc/crawler03/heritrix/output/images/1365759065.jpg
# 3  /0_original/fc/crawler03/heritrix/output/images/1365759068.jpg
# 4  /0_original/fc/crawler03/heritrix/output/images/1365759074.jpg
#
#         file_name file_ext
# 0  1365759028.jpg  .jpg
# 1  1365759053.jpg  .jpg
# 2  1365759065.jpg  .jpg
# 3  1365759068.jpg  .jpg
# 4  1365759074.jpg  .jpg

# %%
# Find the largest ten files:
largest = df.nlargest(20, 'file_size')[['file_size','file_path']]
# Report the size as a human-readable number:
largest['file_size'] = largest['file_size'].apply(humanbytes)
# Show the result:
largest
# Out:
#          file_size  \
# 1738135  171.97 GB
# 1624907  167.82 GB
# 1738049  163.90 GB
# 1738089  157.97 GB
# 1738144  118.22 GB
# 1738095  112.95 GB
# 1738149  107.76 GB
# 1737992  103.44 GB
# 1738090  102.28 GB
# 1738055  102.02 GB
# 1738053  99.91 GB
# 1738150  81.94 GB
# 1738081  75.00 GB
# 2387671  73.36 GB
# 4282     73.29 GB
# 1627133  73.29 GB
# 2388262  71.99 GB
# 1737994  66.37 GB
# 1738057  64.27 GB
# 1705181  63.74 GB
#
#                                                                                                           file_path
# 1738135  /heritrix/output/logs/crawl2-20140610125818/scope.log.cp00016-20141104144708.gz
# 1624907  /datasets/domain-crawl-logs.zip
# 1738049  /heritrix/output/logs/crawl0-20140610125756/scope.log.cp00013-20141104100709.gz
# 1738089  /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00013-20141104144329.gz
# 1738144  /heritrix/output/logs/crawl2-20140610125818/scope.log.cp00043-20140922110002.gz
# 1738095  /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00042-20140922105921.gz
# 1738149  /heritrix/output/logs/crawl3-20130412145049/crawl.log.20130606081851
# 1737992  /heritrix/output/logs/crawl0-20130412144423/crawl.log
# 1738090  /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00022-20141129182502.gz
# 1738055  /heritrix/output/logs/crawl1-20130412144637/crawl.log
# 1738053  /heritrix/output/logs/crawl0-20140610125756/scope.log.cp00042-20140922105836.gz
# 1738150  /heritrix/output/logs/crawl3-20130412145049/crawl3-20130412145049.zip
# 1738081  /heritrix/output/logs/crawl1-20140610125808/crawl1-20140610125808.zip
# 2387671  /heritrix/output/warcs/quarterly/20161001111030/BL-20161009030450532-00956-2025~194.66.232.91~8443.warc.gz
# 4282     /0_original/fc/crawler03/heritrix/output/jisc-1996-2013-dataset/2012.cdx.gz
# 1627133  /datasets/uk-web-1996-2013/2012.cdx.gz
# 2388262  /heritrix/output/warcs/quarterly/20170104102611/BL-20170107155146576-00296-14322~crawler03~8443.warc.gz
# 1737994  /heritrix/output/logs/crawl0-20130412144423/crawl0-20130412144423.zip
# 1738057  /heritrix/output/logs/crawl1-20130412144637/crawl1-20130412144637.zip
# 1705181  /heritrix/output/frequent/20181012103746-edf339eeaf76/logs/crawl.log.cp00031-20181105103747

# %%
# Summarise file counts by file extension:
#df.groupby(df.file_ext).file_ext.count().reset_index(name='count')
df.groupby(df.file_ext).file_ext.count().nlargest(20).reset_index(name='count')
# Out:
#                file_ext   count
# 0   .warc.gz             811500
# 1   .arc.gz              509746
# 2   .arc.os.cdx.gz       465972
# 3   .bl.uk.warc.gz       196276
# 4   .bl.uk.warc.dlx      195737
# 5   .log                 151968
# 6   .xml                 148787
# 7   None                 138079
# 8   .bl.uk.warc.cdx      125331
# 9   .warc.dlx            96435
# 10  .os.cdx.gz           67834
# 11  .wat.gz              67834
# 12  .log.gz              39932
# 13  .bl.uk~8443.warc.gz  27693
# 14  .bl.uk~8444.warc.gz  25880
# 15  .bl.uk~8446.warc.gz  25833
# 16  .warc.dlx.bak        21575
# 17  .bl.uk~8445.warc.gz  20605
# 18  .job                 18081
# 19  .zip                 14044

# %%
# Summarise by collection and year:
df.groupby([df.collection, df.timestamp.dt.year]).file_size.sum().apply(humanbytes).unstack().fillna("")
# Out:
# timestamp          2010      2011      2012       2013       2014       2015  \
# collection
# 0_original
# 1_data                                                  1.14 GB    20.12 GB
# 2_backups
# 9_processing
# blit
# crawls                             12.80 GB
# data                     2.30 GB   2.00 GB              1.11 TB
# datasets                                                308.06 GB
# heritrix                                     170.25 GB  3.68 TB    6.08 TB
# ia                       31.27 TB  4.06 TB              30.04 TB
# logs                                                    10.33 GB   967.44 MB
# lvdata                   14.76 MB                                  450.48 MB
# npld                                         39.88 TB   73.34 TB   90.51 TB
# selective     992.08 GB  9.93 TB   5.21 TB   5.05 TB    3.19 TB    2.32 TB
# tmp           640.72 MB  12.89 GB  1.05 GB   175.18 MB  24.53 MB   91.11 MB
# user                                                               26.88 GB
# wap           108.13 GB
# wayback                                                            239.02 GB
#
# timestamp          2016       2017       2018       2019
# collection
# 0_original    22.36 TB   33.80 GB
# 1_data        161.86 GB  1.72 GB    15.90 GB   318.78 GB
# 2_backups                11.21 GB   47.63 GB   17.42 GB
# 9_processing  165.58 GB  837.87 MB  16.64 GB   12.14 GB
# blit          8.22 GB    106.80 GB  5.50 GB    399.98 MB
# crawls
# data                     115.06 MB             807.61 MB
# datasets                 200.04 GB
# heritrix      558.19 GB  2.67 TB               2.43 TB
# ia                       23.16 MB
# logs          216.11 MB  269.41 MB  468.74 MB  1.77 GB
# lvdata        215.44 KB  550.01 MB  743.90 MB  21.14 MB
# npld          132.57 TB  106.21 TB  122.54 TB  70.73 TB
# selective     400.47 GB
# tmp           25.89 MB   180.53 MB  185.39 MB  205.45 MB
# user          26.60 GB   111.55 GB  317.53 GB  19.60 GB
# wap
# wayback       75.86 GB

# %%
# Overall summary of material:
bd = df.loc[df.stream != 'None'].groupby([df.collection, df.stream, df.timestamp.dt.year, df.kind]).file_size.sum().apply(humanbytes)
#bd['warcs'] = df.loc[df.kind == 'warcs'].groupby([df.stream, df.timestamp.dt.year]).file_size.transform('sum')
bd.reset_index()
bd.unstack(fill_value='')
# Out:
# kind                                   cdx crawl-logs        dlx       logs  \
# collection stream      timestamp
# data       selective   2011
#                        2012
#                        2014
#                        2017
#                        2019
# npld       domain      2013                 497.88 GB             225.81 GB
#                        2014                                       1.40 TB
#                        2015                 235.61 GB             337.29 GB
#                        2016                 1.02 TB               889.37 GB
#                        2017                 827.63 GB             650.10 GB
#                        2018                 1.42 TB
#                        2019                 181.17 GB
#            frequent    2013                                       784.34 MB
#                        2014                                       117.39 GB
#                        2015                                       74.77 GB
#                        2016                 40.20 GB              119.96 GB
#                        2017                 933.57 GB             1.04 TB
#                        2018                 1.27 TB               1.59 TB
#                        2019                 2.07 TB               1.42 TB
#            webrecorder 2016
#                        2019
# selective  selective   2010                 16.17 MB   14.85 GB   1.47 MB
#                        2011                 70.18 GB   114.20 GB  7.63 GB
#                        2012       8.60 GB   29.18 GB   42.42 GB   5.78 GB
#                        2013       32.23 GB  30.83 GB   39.80 GB   7.37 GB
#                        2014       20.84 GB  17.39 GB   24.45 GB   4.92 GB
#                        2015       14.24 GB  15.66 GB   20.36 GB   5.68 GB
#                        2016       2.43 GB   2.21 GB    3.18 GB    1.11 GB
#
# kind                                unknown      viral      warcs  \
# collection stream      timestamp
# data       selective   2011       2.30 GB
#                        2012       2.00 GB
#                        2014       1.11 TB
#                        2017       115.06 MB
#                        2019       807.61 MB
# npld       domain      2013                  4.38 GB    33.90 TB
#                        2014                  4.88 GB    62.13 TB
#                        2015                  4.57 GB    75.49 TB
#                        2016                  8.01 GB    103.80 TB
#                        2017                  4.44 GB    76.97 TB
#                        2018                  2.08 GB    57.58 TB
#                        2019                  451.53 MB  13.87 TB
#            frequent    2013                  99.04 MB   5.25 TB
#                        2014                  34.27 MB   9.69 TB
#                        2015                  271.95 MB  14.37 TB
#                        2016                  2.17 GB    26.69 TB
#                        2017                  119.88 MB  25.78 TB
#                        2018                  255.13 MB  60.65 TB
#                        2019                  166.11 MB  53.19 TB
#            webrecorder 2016                             491.40 MB
#                        2019                             1.14 GB
# selective  selective   2010       87.52 GB              889.69 GB
#                        2011       55.17 GB              9.68 TB
#                        2012       960.12 MB             5.13 TB
#                        2013       343.71 MB             4.94 TB
#                        2014       181.45 MB             3.12 TB
#                        2015       255.82 MB             2.26 TB
#                        2016       44.37 MB              391.49 GB
#
# kind                             warcs-invalid
# collection stream      timestamp
# data       selective   2011
#                        2012
#                        2014
#                        2017
#                        2019
# npld       domain      2013
#                        2014
#                        2015
#                        2016
#                        2017
#                        2018
#                        2019
#            frequent    2013
#                        2014
#                        2015
#                        2016
#                        2017       13.14 GB
#                        2018       17.96 GB
#                        2019
#            webrecorder 2016
#                        2019
# selective  selective   2010
#                        2011       96.74 MB
#                        2012
#                        2013
#                        2014
#                        2015
#                        2016

# %% [markdown]
# Manual Classification Spot Check
# -------------------------------------------------
#
# In at attempt to ensure we've understood the data, we can take the first items of each class and take a look at them, to check the classification makes sense.
#
# This Pandas code only looks at data that's been classified under a content stream. It groups the results by collection, stream, layout, year and kind, and then randomly samples a couple of items for inspection.

# %%
bd = df.loc[df.stream != 'None'].groupby([df.collection, df.stream, df.layout, df.timestamp.dt.year, df.kind]).apply(lambda x: x.sample(2, replace=True))
bd['file_path'].reset_index()
# Out:
#     collection       stream             layout  timestamp           kind  \
# 0    data       selective    wct                2011       unknown
# 1    data       selective    wct                2011       unknown
# 2    data       selective    wct                2012       unknown
# 3    data       selective    wct                2012       unknown
# 4    data       selective    wct                2014       unknown
# 5    data       selective    wct                2014       unknown
# 6    data       selective    wct                2017       unknown
# 7    data       selective    wct                2017       unknown
# 8    data       selective    wct                2019       unknown
# 9    data       selective    wct                2019       unknown
# 10   npld       domain       npld-2013          2013       crawl-logs
# 11   npld       domain       npld-2013          2013       crawl-logs
# 12   npld       domain       npld-2013          2013       logs
# 13   npld       domain       npld-2013          2013       logs
# 14   npld       domain       npld-2013          2013       viral
# 15   npld       domain       npld-2013          2013       viral
# 16   npld       domain       npld-2013          2013       warcs
# 17   npld       domain       npld-2013          2013       warcs
# 18   npld       domain       npld-2013          2014       logs
# 19   npld       domain       npld-2013          2014       logs
# 20   npld       domain       npld-2013          2014       viral
# 21   npld       domain       npld-2013          2014       viral
# 22   npld       domain       npld-2013          2014       warcs
# 23   npld       domain       npld-2013          2014       warcs
# 24   npld       domain       npld-2013          2015       crawl-logs
# 25   npld       domain       npld-2013          2015       crawl-logs
# 26   npld       domain       npld-2013          2015       logs
# 27   npld       domain       npld-2013          2015       logs
# 28   npld       domain       npld-2013          2015       viral
# 29   npld       domain       npld-2013          2015       viral
# 30   npld       domain       npld-2013          2015       warcs
# 31   npld       domain       npld-2013          2015       warcs
# 32   npld       domain       npld-2013          2016       crawl-logs
# 33   npld       domain       npld-2013          2016       crawl-logs
# 34   npld       domain       npld-2013          2016       logs
# 35   npld       domain       npld-2013          2016       logs
# 36   npld       domain       npld-2013          2016       viral
# 37   npld       domain       npld-2013          2016       viral
# 38   npld       domain       npld-2013          2016       warcs
# 39   npld       domain       npld-2013          2016       warcs
# 40   npld       domain       npld-2013          2017       crawl-logs
# 41   npld       domain       npld-2013          2017       crawl-logs
# 42   npld       domain       npld-2013          2017       logs
# 43   npld       domain       npld-2013          2017       logs
# 44   npld       domain       npld-2013          2017       viral
# 45   npld       domain       npld-2013          2017       viral
# 46   npld       domain       npld-2013          2017       warcs
# 47   npld       domain       npld-2013          2017       warcs
# 48   npld       domain       npld-2018          2018       crawl-logs
# 49   npld       domain       npld-2018          2018       crawl-logs
# 50   npld       domain       npld-2018          2018       viral
# 51   npld       domain       npld-2018          2018       viral
# 52   npld       domain       npld-2018          2018       warcs
# 53   npld       domain       npld-2018          2018       warcs
# 54   npld       domain       npld-2018          2019       crawl-logs
# 55   npld       domain       npld-2018          2019       crawl-logs
# 56   npld       domain       npld-2018          2019       viral
# 57   npld       domain       npld-2018          2019       viral
# 58   npld       domain       npld-2018          2019       warcs
# 59   npld       domain       npld-2018          2019       warcs
# 60   npld       frequent     npld-2013          2013       logs
# 61   npld       frequent     npld-2013          2013       logs
# 62   npld       frequent     npld-2013          2013       viral
# 63   npld       frequent     npld-2013          2013       viral
# 64   npld       frequent     npld-2013          2013       warcs
# 65   npld       frequent     npld-2013          2013       warcs
# 66   npld       frequent     npld-2013          2014       logs
# 67   npld       frequent     npld-2013          2014       logs
# 68   npld       frequent     npld-2013          2014       viral
# 69   npld       frequent     npld-2013          2014       viral
# 70   npld       frequent     npld-2013          2014       warcs
# 71   npld       frequent     npld-2013          2014       warcs
# 72   npld       frequent     npld-2013          2015       logs
# 73   npld       frequent     npld-2013          2015       logs
# 74   npld       frequent     npld-2013          2015       viral
# 75   npld       frequent     npld-2013          2015       viral
# 76   npld       frequent     npld-2013          2015       warcs
# 77   npld       frequent     npld-2013          2015       warcs
# 78   npld       frequent     npld-2013          2016       crawl-logs
# 79   npld       frequent     npld-2013          2016       crawl-logs
# 80   npld       frequent     npld-2013          2016       logs
# 81   npld       frequent     npld-2013          2016       logs
# 82   npld       frequent     npld-2013          2016       viral
# 83   npld       frequent     npld-2013          2016       viral
# 84   npld       frequent     npld-2013          2016       warcs
# 85   npld       frequent     npld-2013          2016       warcs
# 86   npld       frequent     npld-2013          2017       crawl-logs
# 87   npld       frequent     npld-2013          2017       crawl-logs
# 88   npld       frequent     npld-2013          2017       logs
# 89   npld       frequent     npld-2013          2017       logs
# 90   npld       frequent     npld-2013          2017       viral
# 91   npld       frequent     npld-2013          2017       viral
# 92   npld       frequent     npld-2013          2017       warcs
# 93   npld       frequent     npld-2013          2017       warcs
# 94   npld       frequent     npld-2013          2017       warcs-invalid
# 95   npld       frequent     npld-2013          2017       warcs-invalid
# 96   npld       frequent     npld-2013          2018       crawl-logs
# 97   npld       frequent     npld-2013          2018       crawl-logs
# 98   npld       frequent     npld-2013          2018       logs
# 99   npld       frequent     npld-2013          2018       logs
# 100  npld       frequent     npld-2013          2018       viral
# 101  npld       frequent     npld-2013          2018       viral
# 102  npld       frequent     npld-2013          2018       warcs
# 103  npld       frequent     npld-2013          2018       warcs
# 104  npld       frequent     npld-2013          2018       warcs-invalid
# 105  npld       frequent     npld-2013          2018       warcs-invalid
# 106  npld       frequent     npld-2013          2019       crawl-logs
# 107  npld       frequent     npld-2013          2019       crawl-logs
# 108  npld       frequent     npld-2013          2019       logs
# 109  npld       frequent     npld-2013          2019       logs
# 110  npld       frequent     npld-2013          2019       viral
# 111  npld       frequent     npld-2013          2019       viral
# 112  npld       frequent     npld-2013          2019       warcs
# 113  npld       frequent     npld-2013          2019       warcs
# 114  npld       frequent     npld-2018          2018       warcs
# 115  npld       frequent     npld-2018          2018       warcs
# 116  npld       frequent     npld-2018          2019       crawl-logs
# 117  npld       frequent     npld-2018          2019       crawl-logs
# 118  npld       frequent     npld-2018          2019       logs
# 119  npld       frequent     npld-2018          2019       logs
# 120  npld       frequent     npld-2018          2019       viral
# 121  npld       frequent     npld-2018          2019       viral
# 122  npld       frequent     npld-2018          2019       warcs
# 123  npld       frequent     npld-2018          2019       warcs
# 124  npld       webrecorder  npld-2018-project  2016       warcs
# 125  npld       webrecorder  npld-2018-project  2016       warcs
# 126  npld       webrecorder  npld-2018-project  2019       warcs
# 127  npld       webrecorder  npld-2018-project  2019       warcs
# 128  selective  selective    wct                2010       crawl-logs
# 129  selective  selective    wct                2010       crawl-logs
# 130  selective  selective    wct                2010       dlx
# 131  selective  selective    wct                2010       dlx
# 132  selective  selective    wct                2010       logs
# 133  selective  selective    wct                2010       logs
# 134  selective  selective    wct                2010       unknown
# 135  selective  selective    wct                2010       unknown
# 136  selective  selective    wct                2010       warcs
# 137  selective  selective    wct                2010       warcs
# 138  selective  selective    wct                2011       crawl-logs
# 139  selective  selective    wct                2011       crawl-logs
# 140  selective  selective    wct                2011       dlx
# 141  selective  selective    wct                2011       dlx
# 142  selective  selective    wct                2011       logs
# 143  selective  selective    wct                2011       logs
# 144  selective  selective    wct                2011       unknown
# 145  selective  selective    wct                2011       unknown
# 146  selective  selective    wct                2011       warcs
# 147  selective  selective    wct                2011       warcs
# 148  selective  selective    wct                2011       warcs-invalid
# 149  selective  selective    wct                2011       warcs-invalid
# 150  selective  selective    wct                2012       cdx
# 151  selective  selective    wct                2012       cdx
# 152  selective  selective    wct                2012       crawl-logs
# 153  selective  selective    wct                2012       crawl-logs
# 154  selective  selective    wct                2012       dlx
# 155  selective  selective    wct                2012       dlx
# 156  selective  selective    wct                2012       logs
# 157  selective  selective    wct                2012       logs
# 158  selective  selective    wct                2012       unknown
# 159  selective  selective    wct                2012       unknown
# 160  selective  selective    wct                2012       warcs
# 161  selective  selective    wct                2012       warcs
# 162  selective  selective    wct                2013       cdx
# 163  selective  selective    wct                2013       cdx
# 164  selective  selective    wct                2013       crawl-logs
# 165  selective  selective    wct                2013       crawl-logs
# 166  selective  selective    wct                2013       dlx
# 167  selective  selective    wct                2013       dlx
# 168  selective  selective    wct                2013       logs
# 169  selective  selective    wct                2013       logs
# 170  selective  selective    wct                2013       unknown
# 171  selective  selective    wct                2013       unknown
# 172  selective  selective    wct                2013       warcs
# 173  selective  selective    wct                2013       warcs
# 174  selective  selective    wct                2014       cdx
# 175  selective  selective    wct                2014       cdx
# 176  selective  selective    wct                2014       crawl-logs
# 177  selective  selective    wct                2014       crawl-logs
# 178  selective  selective    wct                2014       dlx
# 179  selective  selective    wct                2014       dlx
# 180  selective  selective    wct                2014       logs
# 181  selective  selective    wct                2014       logs
# 182  selective  selective    wct                2014       unknown
# 183  selective  selective    wct                2014       unknown
# 184  selective  selective    wct                2014       warcs
# 185  selective  selective    wct                2014       warcs
# 186  selective  selective    wct                2015       cdx
# 187  selective  selective    wct                2015       cdx
# 188  selective  selective    wct                2015       crawl-logs
# 189  selective  selective    wct                2015       crawl-logs
# 190  selective  selective    wct                2015       dlx
# 191  selective  selective    wct                2015       dlx
# 192  selective  selective    wct                2015       logs
# 193  selective  selective    wct                2015       logs
# 194  selective  selective    wct                2015       unknown
# 195  selective  selective    wct                2015       unknown
# 196  selective  selective    wct                2015       warcs
# 197  selective  selective    wct                2015       warcs
# 198  selective  selective    wct                2016       cdx
# 199  selective  selective    wct                2016       cdx
# 200  selective  selective    wct                2016       crawl-logs
# 201  selective  selective    wct                2016       crawl-logs
# 202  selective  selective    wct                2016       dlx
# 203  selective  selective    wct                2016       dlx
# 204  selective  selective    wct                2016       logs
# 205  selective  selective    wct                2016       logs
# 206  selective  selective    wct                2016       unknown
# 207  selective  selective    wct                2016       unknown
# 208  selective  selective    wct                2016       warcs
# 209  selective  selective    wct                2016       warcs
#
#      level_5  \
# 0    745750
# 1    745728
# 2    1103498
# 3    1103484
# 4    1623118
# 5    1623438
# 6    1620730
# 7    1620730
# 8    1623614
# 9    1623613
# 10   1738148
# 11   1738149
# 12   1737994
# 13   1738150
# 14   1919618
# 15   1919550
# 16   2001743
# 17   1961597
# 18   1738093
# 19   1738134
# 20   1919629
# 21   1919742
# 22   1993058
# 23   1944999
# 24   1738125
# 25   1738105
# 26   1738145
# 27   1738052
# 28   1921324
# 29   1921314
# 30   2233241
# 31   2164403
# 32   1799017
# 33   1797780
# 34   1799661
# 35   1797883
# 36   1921133
# 37   1920969
# 38   2133644
# 39   2137373
# 40   1801144
# 41   1801154
# 42   1799954
# 43   1801233
# 44   1921026
# 45   1921164
# 46   2151130
# 47   2224352
# 48   1684923
# 49   1685877
# 50   1629701
# 51   1675871
# 52   1662584
# 53   1683167
# 54   1646335
# 55   1690657
# 56   1641027
# 57   1640617
# 58   1700186
# 59   1699398
# 60   1789272
# 61   1789300
# 62   1921663
# 63   1920873
# 64   2378354
# 65   2096081
# 66   1911830
# 67   1803202
# 68   1921752
# 69   1921661
# 70   2401413
# 71   2419576
# 72   1877011
# 73   1794989
# 74   1921468
# 75   1921464
# 76   2023389
# 77   2425395
# 78   1836421
# 79   1858213
# 80   1858327
# 81   1730672
# 82   1921604
# 83   1921473
# 84   2427083
# 85   2434097
# 86   1858393
# 87   1745786
# 88   1836951
# 89   1781090
# 90   1921916
# 91   1921969
# 92   2039293
# 93   2044960
# 94   2437624
# 95   2028914
# 96   1850601
# 97   1891526
# 98   1894980
# 99   1897258
# 100  1921718
# 101  1920016
# 102  2466544
# 103  2463143
# 104  2441151
# 105  2362638
# 106  1900350
# 107  1770125
# 108  1768729
# 109  1853036
# 110  1921737
# 111  1920459
# 112  2079498
# 113  2481739
# 114  1706799
# 115  1705026
# 116  1716653
# 117  1709655
# 118  1711557
# 119  1712266
# 120  1705947
# 121  1705942
# 122  1715080
# 123  1712587
# 124  156715
# 125  156715
# 126  156737
# 127  156759
# 128  609409
# 129  804481
# 130  714677
# 131  608132
# 132  857944
# 133  1600163
# 134  719694
# 135  773745
# 136  671972
# 137  624714
# 138  1287862
# 139  836953
# 140  705735
# 141  765942
# 142  1051609
# 143  1595519
# 144  1239800
# 145  613714
# 146  773142
# 147  776212
# 148  878685
# 149  860595
# 150  1502222
# 151  920954
# 152  1407469
# 153  1202447
# 154  1391821
# 155  941296
# 156  1605367
# 157  1319098
# 158  1216466
# 159  1174428
# 160  714892
# 161  1362491
# 162  970678
# 163  856250
# 164  1328359
# 165  946248
# 166  1298165
# 167  1371045
# 168  882510
# 169  1362428
# 170  1168729
# 171  1431487
# 172  1473345
# 173  968708
# 174  991764
# 175  795836
# 176  1051898
# 177  1552581
# 178  639309
# 179  730183
# 180  1062919
# 181  1372342
# 182  976080
# 183  1346579
# 184  1412191
# 185  1007170
# 186  1059701
# 187  1514526
# 188  1348057
# 189  1356779
# 190  1302384
# 191  979881
# 192  779315
# 193  1124856
# 194  1510113
# 195  1069928
# 196  1432251
# 197  1025270
# 198  1052628
# 199  1019554
# 200  1207404
# 201  1148626
# 202  626580
# 203  647547
# 204  768750
# 205  1067351
# 206  1206466
# 207  1124123
# 208  1148985
# 209  1341899
#
#                                                                                                                              file_path
# 0    /data/11534346/60395605/60395605/strip.err
# 1    /data/11534346/60395605/60395605/WARCS/BL-60395605-20111001050820-00010-safari.bl.uk.warc.gz
# 2    /data/28180577/55246987/55246987/order.xml
# 3    /data/28180577/55246987/55246987/WARCS/BL-55246987-3.warc.cdx
# 4    /data/videos/Susan_G.flv
# 5    /data/videos/anonymous_56.flv.bak
# 6    /data/prod/heritrix/output/logs/daily/20170702114807/alerts.log.cp00002-20170702234832
# 7    /data/prod/heritrix/output/logs/daily/20170702114807/alerts.log.cp00002-20170702234832
# 8    /data/videos/firefox-var_www.tar.gz
# 9    /data/videos/firefox-opt_red5.tar.gz
# 10   /heritrix/output/logs/crawl3-20130412145049/crawl.log.20130430093604
# 11   /heritrix/output/logs/crawl3-20130412145049/crawl.log.20130606081851
# 12   /heritrix/output/logs/crawl0-20130412144423/crawl0-20130412144423.zip
# 13   /heritrix/output/logs/crawl3-20130412145049/crawl3-20130412145049.zip
# 14   /heritrix/output/viral/crawl1-20130412144637/BL-20130424092807007-00000-24654~crawler02~8444.warc.gz
# 15   /heritrix/output/viral/crawl0-20130412144423/BL-20130412160848476-00000-23518~crawler02~8443.warc.gz
# 16   /heritrix/output/warcs/crawl3-20130412145049/BL-20130505110626622-01900-7659~crawler02~8446.warc.gz
# 17   /heritrix/output/warcs/crawl1-20130412144637/BL-20130505174300727-04437-24654~crawler02~8444.warc.gz
# 18   /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00027-20141208054502.gz
# 19   /heritrix/output/logs/crawl2-20140610125818/scope.log.cp00007-20140625130717.gz
# 20   /heritrix/output/viral/crawl1-20140610125808/BL-20140703064549817-00007-27308~crawler02~8444.warc.gz
# 21   /heritrix/output/viral/crawl2-20140610125818/BL-20141202121735999-00019-22066~crawler02~8445.warc.gz
# 22   /heritrix/output/warcs/crawl2-20140610125818/BL-20141203074319514-07652-22066~crawler02~8445.warc.gz
# 23   /heritrix/output/warcs/crawl0-20140610125756/BL-20141030022647685-03659-6314~crawler02~8443.warc.gz
# 24   /heritrix/output/logs/crawl2-20140610125818/crawl.log.cp00044-20141005041825.gz
# 25   /heritrix/output/logs/crawl2-20140610125818/crawl.log.20141008081017.gz
# 26   /heritrix/output/logs/crawl2-20140610125818/scope.log.gz
# 27   /heritrix/output/logs/crawl0-20140610125756/scope.log.cp00020-20141222200853.gz
# 28   /heritrix/output/viral/dc3-20150827/BL-20150926212228875-00014-23974~crawler04~8446.warc.gz
# 29   /heritrix/output/viral/dc3-20150827/BL-20150903074209815-00004-8100~crawler02~8446.warc.gz
# 30   /heritrix/output/warcs/dc2-20150827/BL-20150928030919109-05961-23893~crawler04~8445.warc.gz
# 31   /heritrix/output/warcs/dc1-20150827/BL-20150904131339332-02355-7938~crawler02~8444.warc.gz
# 32   /heritrix/output/logs/dc1-20150827/crawl.log.cp00029-20151110162042.gz
# 33   /heritrix/output/logs/dc0-20150827/crawl.log.cp00020-20151110152908.gz
# 34   /heritrix/output/logs/dc1-20160810/runtime-errors.log.cp00010-20160903212801
# 35   /heritrix/output/logs/dc0-20150827/runtime-errors.log.cp00009-20151003074557.gz
# 36   /heritrix/output/viral/dc1-20160810/BL-20161216054211439-00053-4336~crawler04.bl.uk~8444.warc.gz
# 37   /heritrix/output/viral/dc0-20160810/BL-20161129034048445-00043-22247~crawler04~8443.warc.gz
# 38   /heritrix/output/warcs/dc0-20160810/BL-20161202132959621-17309-22247~crawler04~8443.warc.gz
# 39   /heritrix/output/warcs/dc0-20160810/BL-20161212232626887-20554-4234~crawler04.bl.uk~8443.warc.gz
# 40   /heritrix/output/logs/dc2-20170515/crawl.log.cp00023-20170724134421
# 41   /heritrix/output/logs/dc2-20170515/crawl.log.cp00033-20170815160617
# 42   /heritrix/output/logs/dc1-20170515/frontier.recover.gz.cp00013-20170630142442
# 43   /heritrix/output/logs/dc2-20170515/nonfatal-errors.log.20170822165251
# 44   /heritrix/output/viral/dc0-20170515/BL-20170927152914313-00039-20124~crawler04.bl.uk~8443.warc.gz
# 45   /heritrix/output/viral/dc1-20170515/BL-20170808235759620-00025-28126~crawler04.bl.uk~8444.warc.gz
# 46   /heritrix/output/warcs/dc0-20170515/BL-20170710021345638-09137-3719~crawler04.bl.uk~8443.warc.gz
# 47   /heritrix/output/warcs/dc1-20170515/BL-20170810205140322-17963-28126~crawler04.bl.uk~8444.warc.gz
# 48   /heritrix/output/dc2018/20181015150658-h3-16/logs/crawl.log.cp00077-20181211150748
# 49   /heritrix/output/dc2018/20181015150658-h3-3/logs/crawl.log.cp00084-20181220150821
# 50   /heritrix/output/dc2018/20180715072213-8b5bc3b887af/viral/BL-VIRAL-20180718084038577-00002-11361~8b5bc3b887af~8443.warc.gz
# 51   /heritrix/output/dc2018/20181015150657-h3-15/viral/BL-VIRAL-20181022045430760-00008-15398~h3-15~8443.warc.gz
# 52   /heritrix/output/dc2018/20180919103935-h3-15/warcs/BL-20180925081808635-00361-6848~h3-15~8443.warc.gz
# 53   /heritrix/output/dc2018/20181015150658-h3-13/warcs/BL-20181115074944240-01649-15398~h3-13~8443.warc.gz
# 54   /heritrix/output/dc2018/20180828135003-h3-7/logs/crawl.log
# 55   /heritrix/output/dc2019/20190621113038/logs/crawl.log.cp00018-20190623113218
# 56   /heritrix/output/dc2018/20180724221454-h3-15/viral/BL-VIRAL-20180801035246317-00002-11362~h3-15~8443.warc.gz
# 57   /heritrix/output/dc2018/20180724221454-h3-14/viral/BL-VIRAL-20180801054801937-00001-11363~h3-14~8443.warc.gz
# 58   /heritrix/output/dc2019/20190703144442/warcs/BL-NPLD-20190710081148788-09560-71~npld-dc-heritrix3-worker-1~8443.warc.gz
# 59   /heritrix/output/dc2019/20190703144442/warcs/BL-NPLD-20190708140452509-08772-71~npld-dc-heritrix3-worker-1~8443.warc.gz
# 60   /heritrix/output/logs/daily-1300-20130422130029/daily-1300-20130422130029.zip
# 61   /heritrix/output/logs/daily-1300-20130523130033/daily-1300-20130523130033.zip
# 62   /heritrix/output/viral/quarterly-1-250200/20131025010022/BL-20131025125044747-00000-27282~opera~8443.warc.gz
# 63   /heritrix/output/viral/daily-1300-20130408130031/BL-20130408124733636-00000-16258~opera~8443.warc.gz
# 64   /heritrix/output/warcs/monthly-081200/20130808110016/BL-20130808110035983-00008-25361~opera~8443.warc.gz
# 65   /heritrix/output/warcs/daily-1000/20131016090029/BL-20131020182335457-00026-25805~opera~8444.warc.gz
# 66   /heritrix/output/logs/weekly-sat0700/20131209104827/20131209104827.zip
# 67   /heritrix/output/logs/latest-20130809093642/20140402091532/20140402091532.zip
# 68   /heritrix/output/viral/sixmonthly-2-051000/20140205100045/BL-20140205121617942-00000-6860~opera~8443.warc.gz
# 69   /heritrix/output/viral/quarterly-1-240200/20141024011206/BL-20141103004334827-00000-26811~opera~8443.warc.gz
# 70   /heritrix/output/warcs/quarterly-1-291000/20140429090059/BL-20140526114657442-00093-14525~opera~8443.warc.gz
# 71   /heritrix/output/warcs/sixmonthly-2-051000/20140812125903/BL-20140923214807228-00207-4238~opera~8443.warc.gz
# 72   /heritrix/output/logs/weekly/20151109120653/20151109120653.zip
# 73   /heritrix/output/logs/daily-1900/20150220190455/20150220190455.zip
# 74   /heritrix/output/viral/monthly/20150706150207/BL-20150707105130340-00000-4984~crawler03~8446.warc.gz
# 75   /heritrix/output/viral/latest-20130809093642/20150120172053/BL-20150210134938988-00000-31982~crawler03~8443.warc.gz
# 76   /heritrix/output/warcs/daily/20151009110418/BL-20151010005857978-00008-4820~crawler03~8444.warc.gz
# 77   /heritrix/output/warcs/weekly/20151214120729/BL-20151214215307277-00043-4902~crawler03~8445.warc.gz
# 78   /heritrix/output/logs/quarterly/20161020154153/crawl.log.cp00003-20161025175031
# 79   /heritrix/output/logs/sixmonthly/20160908143411/crawl.log.cp00017-20161007095423
# 80   /heritrix/output/logs/sixmonthly/20161020160159/runtime-errors.log.cp00002-20161024012455
# 81   /heritrix/output/logs/annual/20161020161712/nonfatal-errors.log.cp00006-20161030201728
# 82   /heritrix/output/viral/quarterly/20160104132733/BL-20160108164553488-00001-13247~crawler03~8443.warc.gz
# 83   /heritrix/output/viral/monthly/20160401111118/BL-20160407113055363-00002-31581~crawler03~8446.warc.gz
# 84   /heritrix/output/warcs/weekly/20160229120854/BL-20160229121111428-00004-20147~crawler03~8445.warc.gz
# 85   /heritrix/output/warcs/weekly/20161114141745/BL-20161127080011320-00284-9170~crawler03.bl.uk~8445.warc.gz
# 86   /heritrix/output/logs/sixmonthly/20161031151355/crawl.log.cp00014-20161124083553
# 87   /heritrix/output/logs/daily/20170426100051/crawl.log.cp00001-20170426160053
# 88   /heritrix/output/logs/quarterly/20170214221843/alerts.log.cp00023-20170220161844
# 89   /heritrix/output/logs/daily-0600/20150323172157/runtime-errors.log.gz
# 90   /heritrix/output/viral/weekly/20170807080059/BL-VIRAL-20170812031140251-00005-62~ukwa-h3-pulse-weekly~8443.warc.gz
# 91   /heritrix/output/viral/weekly/20171016080122/BL-VIRAL-20171020213921383-00005-64~ukwa-h3-pulse-weekly~8443.warc.gz
# 92   /heritrix/output/warcs/daily/20170618100400/BL-20170618122359071-00010-63~ukwa-h3-pulse-daily~8443.warc.gz
# 93   /heritrix/output/warcs/daily/20171017110108/WREN-daily-20171017110108-20171017-20171017110138509-00000-b3r4s0vx.warc.gz
# 94   /heritrix/output/warcs/weekly/20170320105208/BL-20170321105228717-00112-63~ukwa-h3-pulse-weekly~8443.warc.gz.open
# 95   /heritrix/output/warcs/daily/20160703110128/BL-20160703181718160-00018-9345~crawler03~8444.warc.gz.invalid
# 96   /heritrix/output/logs/quarterly/20181001021312/crawl.log.cp00304-20181216021739
# 97   /heritrix/output/logs/weekly/20180501133103/crawl.log.cp00047-20180506013115
# 98   /heritrix/output/logs/weekly/20180827080249/nonfatal-errors.log.cp00024-20180902080318
# 99   /heritrix/output/logs/weekly/20181119090258/alerts.log.cp00022-20181124210318
# 100  /heritrix/output/viral/sixmonthly/20180630230255/BL-VIRAL-20180702172909275-00007-62~ukwa-h3-pulse-sixmonthly~8443.warc.gz
# 101  /heritrix/output/viral/daily/20180714110127/BL-VIRAL-20180715060814006-00001-63~ukwa-h3-pulse-daily~8443.warc.gz
# 102  /heritrix/output/warcs/weekly/20181107101548/BL-20181108221020148-01067-62~ukwa-h3-pulse-weekly~8443.warc.gz
# 103  /heritrix/output/warcs/weekly/20180924080212/BL-20180925014623530-00085-62~ukwa-h3-pulse-weekly~8443.warc.gz
# 104  /heritrix/output/warcs/weekly/20170703070144/BL-20170705130251265-00099-63~ukwa-h3-pulse-weekly~8443.warc.gz.open
# 105  /heritrix/output/warcs/monthly/20171002150237/BL-20171003210348027-00083-63~ukwa-h3-pulse-monthly~8443.warc.gz.open
# 106  /heritrix/output/logs/weekly/20190311090226/crawl.log.cp00021-20190316150245
# 107  /heritrix/output/logs/daily/20190325120235/crawl.log
# 108  /heritrix/output/logs/daily/20190212120252/frontier.recover.gz.cp00001-20190212180331
# 109  /heritrix/output/logs/quarterly/20190701020558/progress-statistics.log.cp00054-20190714140923
# 110  /heritrix/output/viral/sixmonthly/20190630230948/BL-VIRAL-20190702233326306-00006-63~ukwa-h3-pulse-sixmonthly~8443.warc.gz
# 111  /heritrix/output/viral/daily/20190203120151/BL-VIRAL-20190203123025209-00000-63~ukwa-h3-pulse-daily~8443.warc.gz
# 112  /heritrix/output/warcs/daily/20190329120211/BL-20190329131238876-00009-62~ukwa-h3-pulse-daily~8443.warc.gz
# 113  /heritrix/output/warcs/weekly/20190617080234/BL-20190621200311223-00246-63~ukwa-h3-pulse-weekly~8443.warc.gz
# 114  /heritrix/output/frequent/20181213142528-edf339eeaf76/warcs/BL-20181223021130206-01777-15399~edf339eeaf76~8443.warc.gz
# 115  /heritrix/output/frequent/20181005131042-edf339eeaf76/warcs/BL-20181008085520619-00181-6849~edf339eeaf76~8443.warc.gz
# 116  /heritrix/output/frequent-bypm/20190517145608/logs/crawl.log.cp00015-20190529145611
# 117  /heritrix/output/frequent/20190307164628/logs/crawl.log.cp00002-20190308164629
# 118  /heritrix/output/frequent/20190326113906/logs/h3.log
# 119  /heritrix/output/frequent/20190329225505/logs/wp.log
# 120  /heritrix/output/frequent/20181108095851-edf339eeaf76/viral/BL-VIRAL-20181207012237608-00015-15400~edf339eeaf76~8443.warc.gz
# 121  /heritrix/output/frequent/20181108095851-edf339eeaf76/viral/BL-VIRAL-20181201032911233-00010-15400~edf339eeaf76~8443.warc.gz
# 122  /heritrix/output/frequent/20190426153345/warcs/BL-NPLD-20190428051511655-00231-70~heritrix3-worker-1~8443.warc.gz
# 123  /heritrix/output/frequent/20190329225505/warcs/BL-NPLD-20190331122645395-00317-14708~heritrix3-worker-1~8443.warc.gz
# 124  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094149.warc.gz
# 125  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094149.warc.gz
# 126  /1_data/npld/webrecorder/emerging_formats-interactive_fiction/warcs/English_book-of-hours_pwtv5725thkpcihq-20190312175737.warc.gz
# 127  /1_data/npld/webrecorder/emerging_formats-interactive_fiction/warcs/Ingold_insight_qhrft4uivckncjev-20190219105438.warc.gz
# 128  /data/100854/42926802/Logs/crawl.log
# 129  /data/122817/55346120/Logs/crawl.log
# 130  /data/113188/113197/DLX/BL-113197-0.warc.dlx
# 131  /data/100643/100651/DLX/BL-100651-0.warc.dlx
# 132  /data/130828/33521848/Logs/uri-errors.log
# 133  /data/9404417/55345675/Logs/uri-errors.log
# 134  /data/113968/113977/METS.xml
# 135  /data/118519/118532/METS.xml
# 136  /data/104353/104362/WARCS/BL-104362-0.warc.gz
# 137  /data/101989/101997/WARCS/BL-101997-0.warc.gz
# 138  /data/49315964/49512521/Logs/crawl.log
# 139  /data/128322/56820060/Logs/crawl.log
# 140  /data/11108353/60395521/DLX/BL-60395521-20110929045607-00000-safari.bl.uk.warc.dlx
# 141  /data/117188/31850746/DLX/BL-31850746-2.warc.dlx
# 142  /data/26017859/26214585/Logs/uri-errors.log
# 143  /data/9175141/34799779/Logs/local-errors.log
# 144  /data/40271951/58032223/METS.xml
# 145  /data/101311/41680912/order.xml
# 146  /data/118444/56459667/WARCS/BL-56459667-20101216235551-00001-safari.bl.uk.warc.gz
# 147  /data/119228/9306360/WARCS/BL-9306360-0.warc.gz
# 148  /data/133660/8618071/WARCS/.BL-8618071-17.warc.gz.aEk7Pf
# 149  /data/131206/197249/WARCS/wserror.log
# 150  /data/65994845/72089708/WARCS/BL-72089708-20121121052909-00024-safari.bl.uk.warc.cdx
# 151  /data/139712/66127132/WARCS/BL-66127132-20121201232742-00007-safari.bl.uk.warc.cdx
# 152  /data/60588621/63244090/Logs/crawl.log
# 153  /data/33652742/62194346/Logs/crawl.log
# 154  /data/60588186/61768574/DLX/BL-61768574-20111111234150-00012-safari.bl.uk.warc.dlx
# 155  /data/145092/62816547/DLX/BL-62816547-20120206231443-00006-safari.bl.uk.warc.dlx
# 156  /data/9404456/60817779/Logs/uri-errors.log
# 157  /data/56197153/61767816/Logs/uri-errors.log
# 158  /data/36077600/60817905/METS.xml
# 159  /data/32145544/66126656/order.xml
# 160  /data/113208/63242912/WARCS/BL-63242912-20120303055227-00007-safari.bl.uk.warc.gz
# 161  /data/60293156/63242592/WARCS/BL-63242592-20120223010016-00000-safari.bl.uk.warc.gz
# 162  /data/172294179/179339358/WARCS/BL-179339358-20130719181530-00027-safari.bl.uk.warc.cdx
# 163  /data/130493/66126147/WARCS/BL-66126147-20121109002333-00009-safari.bl.uk.warc.cdx
# 164  /data/57344099/160137252/Logs/crawl.log
# 165  /data/14811174/66128219/Logs/crawl.log
# 166  /data/49905690/66129904/DLX/BL-66129904-20130119112231-00024-safari.bl.uk.warc.dlx
# 167  /data/60293201/162365786/DLX/BL-162365786-20130806000031-00000-safari.bl.uk.warc.dlx
# 168  /data/13402112/181764199/Logs/uri-errors.log
# 169  /data/60293155/66486280/Logs/uri-errors.log
# 170  /data/32145442/66127855/order.xml
# 171  /data/63275048/171803018/order.xml
# 172  /data/65208481/65733761/WARCS/BL-65733761-20121103051528-00000-safari.bl.uk.warc.gz
# 173  /data/172294145/171802848/WARCS/BL-171802848-20130702211035-00004-safari.bl.uk.warc.gz
# 174  /data/218955790/218431628/WARCS/BL-218431628-20140113171235-00010-safari.bl.uk.warc.cdx
# 175  /data/122171/203423903/WARCS/BL-203423903-20140207010137-00044-safari.bl.uk.warc.cdx
# 176  /data/26017867/251592951/Logs/crawl.log
# 177  /data/8486916/218432140/Logs/crawl.log
# 178  /data/102148/236094470/DLX/BL-236094470-20140723100347-00187-safari.bl.uk.warc.dlx
# 179  /data/11534337/203424597/DLX/BL-203424597-20131231084909-00679-safari.bl.uk.warc.dlx
# 180  /data/266338339/265879838/Logs/local-errors.log
# 181  /data/60293201/236093651/Logs/local-errors.log
# 182  /data/182124549/203423849/order.xml
# 183  /data/59113617/203424801/METS.xml
# 184  /data/61538349/265879609/WARCS/BL-265879609-20141207230114-00000-safari.bl.uk.warc.gz
# 185  /data/235438124/236094052/WARCS/BL-236094052-20140410090812-00002-safari.bl.uk.warc.gz
# 186  /data/264142869/293671190/WARCS/BL-293671190-20150903222336-00002-safari.bl.uk.warc.cdx
# 187  /data/66158885/285476103/WARCS/BL-285476103-20150429224831-00043-safari.bl.uk.warc.cdx
# 188  /data/59113632/276463621/Logs/crawl.log
# 189  /data/59703302/293671217/Logs/crawl.log
# 190  /data/50659384/265880802/DLX/BL-265880802-20150126070315-00000-safari.bl.uk.warc.dlx
# 191  /data/191037444/293667084/DLX/BL-293667084-20150211014841-00000-safari.bl.uk.warc.dlx
# 192  /data/119715/321814554/Logs/uri-errors.log
# 193  /data/293863572/293667809/Logs/uri-errors.log
# 194  /data/66158799/293671411/METS.xml
# 195  /data/266338429/285476031/METS.xml
# 196  /data/63275049/293668480/WARCS/BL-293668480-20150612035511-00004-safari.bl.uk.warc.gz
# 197  /data/235438241/339379440/WARCS/BL-339379440-20151121230120-00000-safari.bl.uk.warc.gz
# 198  /data/261128198/339378911/WARCS/BL-339378911-20160202072718-00005-safari.bl.uk.warc.cdx
# 199  /data/235438240/339380381/WARCS/BL-339380381-20151221020223-00001-safari.bl.uk.warc.cdx
# 200  /data/339312745/339382161/Logs/crawl.log
# 201  /data/31260808/339381139/Logs/crawl.log
# 202  /data/102036/339379312/DLX/BL-339379312-20160125104811-00000-safari.bl.uk.warc.dlx
# 203  /data/102148/339380881/DLX/BL-339380881-20160109155316-00484-safari.bl.uk.warc.dlx
# 204  /data/117399/339379220/Logs/uri-errors.log
# 205  /data/266338355/339380478/Logs/uri-errors.log
# 206  /data/339312691/339380712/order.xml
# 207  /data/293863570/339380983/order.xml
# 208  /data/31260808/339382131/WARCS/BL-339382131-20160222230245-00000-safari.bl.uk.warc.gz
# 209  /data/59113543/339379066/WARCS/BL-339379066-20160207010803-00001-safari.bl.uk.warc.gz

# %% [markdown]
# Timestamp Checks
# ----------------------------
#
# Processing the data downstream, we came across this event.
#
#    duplicate key value (filename,job_name,job_launch)=('crawl.log','dc2019','20190524') violates unique constraint "primary"
#
# For more recent crawls, the fine-grained timestamp should not be that short a string.

# %%
df.loc[df['job'] == 'dc2019'].head()
# Out:
#          recognised collection  stream     job     layout        kind  \
# 1689385  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689386  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689387  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689388  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689389  True        npld       domain  dc2019  npld-2018  crawl-logs
#
#         permissions  number_of_replicas user_id    group_id  file_size  \
# 1689385  -rw-r--r--  3                   hdfs    supergroup  0
# 1689386  -rw-r--r--  3                   hdfs    supergroup  0
# 1689387  -rw-r--r--  3                   hdfs    supergroup  860
# 1689388  -rw-r--r--  3                   hdfs    supergroup  0
# 1689389  -rw-r--r--  3                   hdfs    supergroup  0
#
#                  modified_at           timestamp  \
# 1689385  2019-06-19T11:35:00 2019-06-19 11:35:00
# 1689386  2019-06-20T16:44:00 2019-06-20 16:44:00
# 1689387  2019-06-19T11:35:00 2019-06-19 11:35:00
# 1689388  2019-06-20T16:45:00 2019-06-20 16:45:00
# 1689389  2019-06-20T16:45:00 2019-06-20 16:45:00
#
#                                                                             file_path  \
# 1689385  /heritrix/output/dc2019/20190524140702/logs/crawl.log
# 1689386  /heritrix/output/dc2019/20190524140702/logs/crawl.log.cp00001-20190524141211
# 1689387  /heritrix/output/dc2019/20190524141331/logs/crawl.log
# 1689388  /heritrix/output/dc2019/20190524141331/logs/crawl.log.cp00001-20190525141333
# 1689389  /heritrix/output/dc2019/20190524141331/logs/crawl.log.cp00002-20190526141333
#
#                                 file_name                     file_ext
# 1689385  crawl.log                         .log
# 1689386  crawl.log.cp00001-20190524141211  .log.cp00001-20190524141211
# 1689387  crawl.log                         .log
# 1689388  crawl.log.cp00001-20190525141333  .log.cp00001-20190525141333
# 1689389  crawl.log.cp00002-20190526141333  .log.cp00002-20190526141333

# %%
df.loc[df['job'] == 'bl-your_stories'].head()
# Out:
#         recognised collection       stream              job  \
# 156711  True        npld       webrecorder  bl-your_stories
# 156712  True        npld       webrecorder  bl-your_stories
# 156713  True        npld       webrecorder  bl-your_stories
# 156714  True        npld       webrecorder  bl-your_stories
# 156715  True        npld       webrecorder  bl-your_stories
#
#                    layout   kind permissions  number_of_replicas user_id  \
# 156711  npld-2018-project  warcs  -rw-r--r--  3                   hdfs
# 156712  npld-2018-project  warcs  -rw-r--r--  3                   hdfs
# 156713  npld-2018-project  warcs  -rw-r--r--  3                   hdfs
# 156714  npld-2018-project  warcs  -rw-r--r--  3                   hdfs
# 156715  npld-2018-project  warcs  -rw-r--r--  3                   hdfs
#
#           group_id  file_size          modified_at           timestamp  \
# 156711  supergroup  12729735   2016-12-30T11:59:00 2016-12-30 11:59:00
# 156712  supergroup  95733865   2016-12-30T11:59:00 2016-12-30 11:59:00
# 156713  supergroup  95733865   2016-12-30T11:59:00 2016-12-30 11:59:00
# 156714  supergroup  95733864   2016-12-30T11:59:00 2016-12-30 11:59:00
# 156715  supergroup  95733863   2016-12-30T11:59:00 2016-12-30 11:59:00
#
#                                                                               file_path  \
# 156711  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814093821.warc.gz
# 156712  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094134.warc.gz
# 156713  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094141.warc.gz
# 156714  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094146.warc.gz
# 156715  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094149.warc.gz
#
#                                file_name                       file_ext
# 156711  www.bl.uk-20150814093821.warc.gz  .bl.uk-20150814093821.warc.gz
# 156712  www.bl.uk-20150814094134.warc.gz  .bl.uk-20150814094134.warc.gz
# 156713  www.bl.uk-20150814094141.warc.gz  .bl.uk-20150814094141.warc.gz
# 156714  www.bl.uk-20150814094146.warc.gz  .bl.uk-20150814094146.warc.gz
# 156715  www.bl.uk-20150814094149.warc.gz  .bl.uk-20150814094149.warc.gz

# %% [markdown]
# This notebook provides an environment for testing changes to the HDFS path parser we use to classify and track the contents of HDFS.
#
# To see how things will change, we can compare what we get against the current production results: http://intranet.wa.bl.uk/ukwa-reports/reports/hdfs/
#
# First we need to get an up-to-date copy of the full listing of files on HDFS. These are generated daily and placed on HDFS.

# %%
# !ls -lh /mnt/gluster/ingest/task-state/hdfs/current/
# Out:
# total 2.0G
# -rw-r--r--. 1 root root 525M Jul 11 01:12 current-hdfs-all-files-list.csv
# -rw-r--r--. 1 root root  37M Jul 11 01:48 current-hdfs-all-files-list.csv.gz
# -rw-r--r--. 1 root root 525M Jul 10 01:12 current-hdfs-all-files-list.csv.old
# -rw-r--r--. 1 root root 928M Jul 11 01:44 current-hdfs-parsed-paths.csv

# %%
# This cell is tagged `parameters` (use View > Cell Toolbar > Tags to modify)
file_list_csv = '/mnt/gluster/ingest/task-state/hdfs/current/current-hdfs-all-files-list.csv'
parsed_files_csv = 'test/hdfs-parsed-paths.csv'

# %% [markdown]
# Now we can run the path parser on it:

# %%
import os
import sys
import re
import csv
import enum
import datetime
import logging

# Set up a logger to give some feedback:
logger = logging.getLogger()
    
# Expected headers for the raw HDFS file list CSV, see ListAllFilesOnHDFSToLocalFile
file_list_headers = ['permissions', 'number_of_replicas', 'userid', 'groupid', 'filesize', 'modified_at', 'filename']


class HdfsPathParser(object):
    """
    This class takes a HDFS file path and determines what, if any, crawl it belongs to, etc.
    """

    @staticmethod
    def field_names():
        """This returns the extended set of field names that this class derives from the basic listing."""
        return ['recognised', 'collection', 'stream','job', 'layout', 'kind', 'permissions', 'number_of_replicas', 'user_id', 'group_id', 'file_size', 'modified_at', 'timestamp', 'file_path', 'file_name', 'file_ext']

    def __init__(self, item):
        """
        Given a string containing the absolute HDFS file path, parse it to work our what kind of thing it is.

        Determines crawl job, launch, kind of file, etc.

        For WCT-era selective content, the job is the Target ID and the launch is the Instance ID.

        :param file_path:
        """

        # Perform basic processing:
        # ------------------------------------------------
        # To be captured later
        self.recognised = False
        self.collection = None
        self.stream = None
        self.layout = None
        self.job = None
        self.kind = 'unknown'
        # From the item listing:
        self.permissions = item['permissions']
        self.number_of_replicas = item['number_of_replicas']
        self.user_id = item['userid']
        self.group_id = item['groupid']
        self.file_size = item['filesize']
        self.modified_at = item['modified_at']
        self.file_path = item['filename']
        # Derived:
        self.file_name = os.path.basename(self.file_path)
        first_dot_at = self.file_name.find('.')
        if first_dot_at != -1:
            self.file_ext = self.file_name[first_dot_at:]
        else:
            self.file_ext = None
        self.timestamp_datetime = datetime.datetime.strptime(item['modified_at'], "%Y-%m-%dT%H:%M:%S")
        self.timestamp = self.timestamp_datetime.isoformat()
        self.launch_datetime = None

        # Look for different filename patterns:
        # ------------------------------------------------
        self.analyse_file_path()

        # Now Add data based on file kind and file name...
        # ------------------------------------------------

        # Distinguish 'bad' crawl files, e.g. warc.gz.open files that are down as warcs
        if self.kind == 'warcs':
            if not self.file_name.endswith(".warc.gz"):
                # The older selective crawls allowed CDX files alongside the WARCs:
                if self.collection == 'selective' and self.file_name.endswith(".warc.cdx"):
                    self.kind = 'cdx'
                else:
                    self.kind = 'warcs-invalid'
            else:
                # Attempt to parse file timestamp out of filename,
                # Store ISO formatted date in self.timestamp, datetime object in self.timestamp_datetime
                mwarc = re.search('^.*-([12][0-9]{16})-.*\.warc\.gz$', self.file_name)
                if mwarc:
                    self.timestamp_datetime = datetime.datetime.strptime(mwarc.group(1), "%Y%m%d%H%M%S%f")
                    self.timestamp = self.timestamp_datetime.isoformat()
                else:
                    if self.stream and self.launch_datetime:
                        # fall back on launch datetime:
                        self.timestamp_datetime = self.launch_datetime
                        self.timestamp = self.timestamp_datetime.isoformat()

        # Distinguish crawl logs from other logs...
        if self.kind == 'logs':
            if self.file_name.startswith("crawl.log"):
                self.kind = 'crawl-logs'

    def analyse_file_path(self):
        """
        This function analyses the file path to classify the item.
        """
        
        #
        # Selective era layout /data/<target-id>/<instance-id>/<kind>
        #
        if re.search('^/data/', self.file_path ):
            self.layout = 'wct'
            self.collection = 'selective'
            self.stream = CrawlStream.selective
            mby  = re.search('^/data/([0-9]+)/([0-9]+)/(DLX/|Logs/|WARCS/|)([^\/]+)$', self.file_path)
            if mby:
                self.recognised = True
                # In this case the job is the Target ID and the launch is the Instance ID:
                (self.job, self.launch, self.kind, self.file_name) = mby.groups()
                self.kind = self.kind.lower().strip('/')
                if self.kind == '':
                    self.kind = 'unknown'
                self.launch_datetime = None
                
        # 
        # First NPLD era file layout /heritrix/output/(warcs|viral|logs)/<job>...
        #
        elif re.search('^/heritrix/output/(warcs|viral|logs)/.*', self.file_path ):
            self.layout = 'npld-2013'
            self.collection = 'npld'
            # Original domain-crawl layout: kind/job (need to look for this first)
            mdc  = re.search('^/heritrix/output/(warcs|viral|logs)/(dc|crawl)[0-3]\-([0-9]{8}|[0-9]{14})/([^\/]+)$', self.file_path)
            # original frequent crawl layout: kind/job/launch-id
            mfc  = re.search('^/heritrix/output/(warcs|viral|logs)/([a-z\-0-9]+)[-/]([0-9]{12,14})/([^\/]+)$', self.file_path)
            if mdc:
                self.recognised = True
                self.stream = CrawlStream.domain
                (self.kind, self.job, self.launch, self.file_name) = mdc.groups()
                self.job = 'dc%s' % self.launch[0:4] # Overriding old job name.
                # Cope with variation in folder naming - all DC crawlers run as a single launch on the same day:
                if len(self.launch) > 8:
                    self.launch = self.launch[0:8]
                self.launch_datetime = datetime.datetime.strptime(self.launch, "%Y%m%d")
            elif mfc:
                self.recognised = True
                self.stream = CrawlStream.frequent
                (self.kind, self.job, self.launch, self.file_name) = mfc.groups()
                self.launch_datetime = datetime.datetime.strptime(self.launch, "%Y%m%d%H%M%S")

        # 
        # Second NPLD era file layout /heritrix/output/<job>/<launch>(warcs|viral|logs)/...
        #
        elif re.search('^/heritrix/output/(dc2.+|frequent.*)/.*', self.file_path ):
            self.layout = 'npld-2018'
            self.collection = 'npld'
            # 2019 frequent-crawl layout: job/launch-id/kind (same as DC now?
            mfc2 = re.search('^/heritrix/output/([a-z\-0-9]+)/([0-9]{12,14})[^/]*/(warcs|viral|logs)/([^\/]+)$', self.file_path)
            if mfc2:
                self.recognised = True
                (self.job, self.launch, self.kind, self.file_name) = mfc2.groups()
                # Recognise domain crawls:
                if self.job.startswith('dc2'):
                    self.stream = CrawlStream.domain
                else:
                    self.stream = CrawlStream.frequent
                # Parse a launch datetime
                self.launch_datetime = datetime.datetime.strptime(self.launch, "%Y%m%d%H%M%S")
                
        # 
        # Files stored but intended for deletion.
        #
        elif self.file_path.startswith('/_to_be_deleted/'):
            self.recognised = True
            self.kind = 'to-be-deleted'
            self.file_name = os.path.basename(self.file_path)
            
        #
        # If un-matched, default to classifying by top-level folder.
        #
        else:
            self.collection = self.file_path.split(os.path.sep)[1]
            self.file_name = os.path.basename(self.file_path)
        

    def to_dict(self):
        d = dict()
        for f in self.field_names():
            d[f] = str(getattr(self,f,""))
        return d


class CrawlStream(enum.Enum):
    """
    An enumeration of the different crawl streams.
    """

    selective = 1
    """'selective' is permissions-based collection. e.g. Pre-NPLD collections."""

    frequent = 2
    """ 'frequent' covers NPLD crawls of curated sites."""

    domain = 3
    """ 'domain' refers to NPLD domain crawls."""

    def __str__(self):
        return self.name

# Now parse the input and classify the entries:
lines = 0
with open(parsed_files_csv, 'w') as fout:
    # Set up output file:
    writer = csv.DictWriter(fout, fieldnames=HdfsPathParser.field_names())
    writer.writeheader()
    with open(file_list_csv, 'r') as fin:
        reader = csv.DictReader(fin, fieldnames=file_list_headers)
        for item in reader:
            # Skip the first line:
            if item['filesize'] == 'filesize':
                continue
            # Output the enriched version:
            p = HdfsPathParser(item)
            writer.writerow(p.to_dict())
            lines += 1
            if lines%500000 == 0:
                logger.warning("Processed %i lines..." % lines)

logger.warning("Done. Processed a total of %i lines." % lines)
# Out:
# Processed 500000 lines...
# Processed 1000000 lines...
# Processed 1500000 lines...
# Processed 2000000 lines...
# Processed 2500000 lines...
# Processed 3000000 lines...
# Processed 3500000 lines...
# Done. Processed a total of 3764529 lines.

# %%
import pandas as pd
from data_formatters import humanbytes

# Enable inline plots
# %matplotlib inline

# Do not truncate file path display:
pd.set_option('display.max_colwidth', -1)

# Show more rows
pd.options.display.max_rows = 4000

# Load the data:
df = pd.read_csv(parsed_files_csv)

# Interpret modified_at and timestamp as a datetimes:
df.timestamp = pd.to_datetime(df.timestamp)

# Ignore the to-be-deleted data:
df = df.loc[df['kind'] != 'to-be-deleted']

# Show us the data:
df.head()
# Out:
#    recognised  collection stream   job layout     kind permissions  \
# 0  False       0_original  None   None  None   unknown  -rw-r--r--
# 1  False       0_original  None   None  None   unknown  -rw-r--r--
# 2  False       0_original  None   None  None   unknown  -rw-r--r--
# 3  False       0_original  None   None  None   unknown  -rw-r--r--
# 4  False       0_original  None   None  None   unknown  -rw-r--r--
#
#    number_of_replicas user_id    group_id  file_size          modified_at  \
# 0  3                   hdfs    supergroup  206979     2016-05-24T10:55:00
# 1  3                   hdfs    supergroup  259004     2016-05-24T10:55:00
# 2  3                   hdfs    supergroup  137950     2016-05-24T10:56:00
# 3  3                   hdfs    supergroup  157173     2016-05-24T10:56:00
# 4  3                   hdfs    supergroup  121905     2016-05-24T10:56:00
#
#             timestamp  \
# 0 2016-05-24 10:55:00
# 1 2016-05-24 10:55:00
# 2 2016-05-24 10:56:00
# 3 2016-05-24 10:56:00
# 4 2016-05-24 10:56:00
#
#                                                         file_path  \
# 0  /0_original/fc/crawler03/heritrix/output/images/1365759028.jpg
# 1  /0_original/fc/crawler03/heritrix/output/images/1365759053.jpg
# 2  /0_original/fc/crawler03/heritrix/output/images/1365759065.jpg
# 3  /0_original/fc/crawler03/heritrix/output/images/1365759068.jpg
# 4  /0_original/fc/crawler03/heritrix/output/images/1365759074.jpg
#
#         file_name file_ext
# 0  1365759028.jpg  .jpg
# 1  1365759053.jpg  .jpg
# 2  1365759065.jpg  .jpg
# 3  1365759068.jpg  .jpg
# 4  1365759074.jpg  .jpg

# %%
# Find the largest ten files:
largest = df.nlargest(20, 'file_size')[['file_size','file_path']]
# Report the size as a human-readable number:
largest['file_size'] = largest['file_size'].apply(humanbytes)
# Show the result:
largest
# Out:
#          file_size  \
# 1734872  171.97 GB
# 1624639  167.82 GB
# 1734786  163.90 GB
# 1734826  157.97 GB
# 1734881  118.22 GB
# 1734832  112.95 GB
# 1734886  107.76 GB
# 1734729  103.44 GB
# 1734827  102.28 GB
# 1734792  102.02 GB
# 1734790  99.91 GB
# 1734887  81.94 GB
# 1734818  75.00 GB
# 2382934  73.36 GB
# 4282     73.29 GB
# 1626865  73.29 GB
# 2383525  71.99 GB
# 1734731  66.37 GB
# 1734794  64.27 GB
# 1702200  63.74 GB
#
#                                                                                                           file_path
# 1734872  /heritrix/output/logs/crawl2-20140610125818/scope.log.cp00016-20141104144708.gz
# 1624639  /datasets/domain-crawl-logs.zip
# 1734786  /heritrix/output/logs/crawl0-20140610125756/scope.log.cp00013-20141104100709.gz
# 1734826  /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00013-20141104144329.gz
# 1734881  /heritrix/output/logs/crawl2-20140610125818/scope.log.cp00043-20140922110002.gz
# 1734832  /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00042-20140922105921.gz
# 1734886  /heritrix/output/logs/crawl3-20130412145049/crawl.log.20130606081851
# 1734729  /heritrix/output/logs/crawl0-20130412144423/crawl.log
# 1734827  /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00022-20141129182502.gz
# 1734792  /heritrix/output/logs/crawl1-20130412144637/crawl.log
# 1734790  /heritrix/output/logs/crawl0-20140610125756/scope.log.cp00042-20140922105836.gz
# 1734887  /heritrix/output/logs/crawl3-20130412145049/crawl3-20130412145049.zip
# 1734818  /heritrix/output/logs/crawl1-20140610125808/crawl1-20140610125808.zip
# 2382934  /heritrix/output/warcs/quarterly/20161001111030/BL-20161009030450532-00956-2025~194.66.232.91~8443.warc.gz
# 4282     /0_original/fc/crawler03/heritrix/output/jisc-1996-2013-dataset/2012.cdx.gz
# 1626865  /datasets/uk-web-1996-2013/2012.cdx.gz
# 2383525  /heritrix/output/warcs/quarterly/20170104102611/BL-20170107155146576-00296-14322~crawler03~8443.warc.gz
# 1734731  /heritrix/output/logs/crawl0-20130412144423/crawl0-20130412144423.zip
# 1734794  /heritrix/output/logs/crawl1-20130412144637/crawl1-20130412144637.zip
# 1702200  /heritrix/output/frequent/20181012103746-edf339eeaf76/logs/crawl.log.cp00031-20181105103747

# %%
# Summarise file counts by file extension:
#df.groupby(df.file_ext).file_ext.count().reset_index(name='count')
df.groupby(df.file_ext).file_ext.count().nlargest(20).reset_index(name='count')
# Out:
#                file_ext   count
# 0   .warc.gz             806034
# 1   .arc.gz              509746
# 2   .arc.os.cdx.gz       465972
# 3   .bl.uk.warc.gz       196276
# 4   .bl.uk.warc.dlx      195737
# 5   .log                 151926
# 6   .xml                 148755
# 7   None                 137759
# 8   .bl.uk.warc.cdx      125331
# 9   .warc.dlx            96435
# 10  .os.cdx.gz           67834
# 11  .wat.gz              67834
# 12  .log.gz              39932
# 13  .bl.uk~8443.warc.gz  27693
# 14  .bl.uk~8444.warc.gz  25880
# 15  .bl.uk~8446.warc.gz  25833
# 16  .warc.dlx.bak        21575
# 17  .bl.uk~8445.warc.gz  20605
# 18  .job                 18081
# 19  .zip                 14044

# %%
# Summarise by collection and year:
df.groupby([df.collection, df.timestamp.dt.year]).file_size.sum().apply(humanbytes).unstack().fillna("")
# Out:
# timestamp          2010      2011      2012       2013       2014       2015  \
# collection
# 0_original
# 1_data                                                  1.14 GB    20.12 GB
# 2_backups
# 9_processing
# blit
# crawls                             12.80 GB
# datasets                                                308.06 GB
# heritrix                                                3.68 TB    6.07 TB
# ia                       31.27 TB  4.06 TB              30.04 TB
# logs                                                    10.33 GB   967.44 MB
# lvdata                   14.76 MB                                  450.48 MB
# npld                                         40.05 TB   73.34 TB   90.53 TB
# selective     992.08 GB  9.93 TB   5.22 TB   5.05 TB    4.30 TB    2.32 TB
# tmp           640.72 MB  12.89 GB  1.05 GB   175.18 MB  24.53 MB   91.11 MB
# user                                                               26.88 GB
# wap           108.13 GB
# wayback                                                            239.02 GB
#
# timestamp          2016       2017       2018       2019
# collection
# 0_original    22.36 TB   33.80 GB
# 1_data        162.35 GB  1.72 GB    15.90 GB   319.82 GB
# 2_backups                11.21 GB   47.63 GB   16.85 GB
# 9_processing  165.58 GB  837.87 MB  16.64 GB   11.90 GB
# blit          8.22 GB    106.80 GB  5.50 GB    399.98 MB
# crawls
# datasets                 200.04 GB
# heritrix      555.70 GB  593.04 GB             2.43 TB
# ia                       23.16 MB
# logs          216.11 MB  269.41 MB  468.74 MB  1.74 GB
# lvdata        215.44 KB  550.01 MB  743.90 MB  21.14 MB
# npld          132.57 TB  108.30 TB  122.54 TB  65.24 TB
# selective     400.47 GB  115.06 MB             807.61 MB
# tmp           25.89 MB   180.53 MB  185.39 MB  200.69 MB
# user          26.60 GB   111.55 GB  317.53 GB  19.40 GB
# wap
# wayback       75.86 GB

# %%
# Overall summary of material:
bd = df.loc[df.stream != 'None'].groupby([df.collection, df.stream, df.timestamp.dt.year, df.kind]).file_size.sum().apply(humanbytes)
#bd['warcs'] = df.loc[df.kind == 'warcs'].groupby([df.stream, df.timestamp.dt.year]).file_size.transform('sum')
bd.reset_index()
bd.unstack(fill_value='')
# Out:
# kind                                 cdx crawl-logs        dlx       logs  \
# collection stream    timestamp
# npld       domain    2013                 497.88 GB             225.81 GB
#                      2014                                       1.40 TB
#                      2015                 235.61 GB             337.29 GB
#                      2016                 1.02 TB               889.37 GB
#                      2017                 827.63 GB             650.10 GB
#                      2018                 1.42 TB
#                      2019                 158.13 GB
#            frequent  2013                                       784.34 MB
#                      2014                                       117.39 GB
#                      2015                                       74.77 GB
#                      2016                 40.20 GB              119.96 GB
#                      2017                 933.57 GB             1.04 TB
#                      2018                 1.27 TB               1.59 TB
#                      2019                 2.02 TB               1.35 TB
# selective  selective 2010                 16.17 MB   14.85 GB   1.47 MB
#                      2011                 70.18 GB   114.20 GB  7.63 GB
#                      2012       8.60 GB   29.18 GB   42.42 GB   5.78 GB
#                      2013       32.23 GB  30.83 GB   39.80 GB   7.37 GB
#                      2014       20.84 GB  17.39 GB   24.45 GB   4.92 GB
#                      2015       14.24 GB  15.66 GB   20.36 GB   5.68 GB
#                      2016       2.43 GB   2.21 GB    3.18 GB    1.11 GB
#                      2017
#                      2019
#
# kind                              unknown      viral      warcs warcs-invalid
# collection stream    timestamp
# npld       domain    2013                  4.38 GB    33.90 TB
#                      2014                  4.88 GB    62.13 TB
#                      2015                  4.57 GB    75.49 TB
#                      2016                  8.01 GB    103.80 TB
#                      2017                  4.44 GB    76.97 TB
#                      2018                  2.08 GB    57.58 TB
#                      2019                  341.54 MB  11.10 TB
#            frequent  2013                  99.04 MB   5.25 TB
#                      2014                  34.27 MB   9.69 TB
#                      2015                  271.95 MB  14.37 TB
#                      2016                  2.17 GB    26.69 TB
#                      2017                  119.88 MB  25.78 TB   13.14 GB
#                      2018                  255.13 MB  60.65 TB   17.96 GB
#                      2019                  160.42 MB  50.61 TB
# selective  selective 2010       87.52 GB              889.69 GB
#                      2011       57.46 GB              9.68 TB    96.74 MB
#                      2012       2.96 GB               5.13 TB
#                      2013       343.71 MB             4.94 TB
#                      2014       1.11 TB               3.12 TB
#                      2015       255.82 MB             2.26 TB
#                      2016       44.37 MB              391.49 GB
#                      2017       115.06 MB
#                      2019       807.61 MB

# %% [markdown]
# Manual Classification Spot Check
# -------------------------------------------------
#
# In at attempt to ensure we've understood the data, we can take the first items of each class and take a look at them, to check the classification makes sense.
#
# This Pandas code only looks at data that's been classified under a content stream. It groups the results by collection, stream, layout, year and kind, and then randomly samples a couple of items for inspection.

# %%
bd = df.loc[df.stream != 'None'].groupby([df.collection, df.stream, df.layout, df.timestamp.dt.year, df.kind]).apply(lambda x: x.sample(2, replace=True))
bd['file_path'].reset_index()
# Out:
#     collection     stream     layout  timestamp           kind  level_5  \
# 0    npld       domain     npld-2013  2013       crawl-logs     1734729
# 1    npld       domain     npld-2013  2013       crawl-logs     1734730
# 2    npld       domain     npld-2013  2013       logs           1734835
# 3    npld       domain     npld-2013  2013       logs           1734835
# 4    npld       domain     npld-2013  2013       viral          1915650
# 5    npld       domain     npld-2013  2013       viral          1915854
# 6    npld       domain     npld-2013  2013       warcs          1922594
# 7    npld       domain     npld-2013  2013       warcs          1949788
# 8    npld       domain     npld-2013  2014       logs           1734822
# 9    npld       domain     npld-2013  2014       logs           1734877
# 10   npld       domain     npld-2013  2014       viral          1915653
# 11   npld       domain     npld-2013  2014       viral          1915666
# 12   npld       domain     npld-2013  2014       warcs          1967514
# 13   npld       domain     npld-2013  2014       warcs          2013603
# 14   npld       domain     npld-2013  2015       crawl-logs     1734802
# 15   npld       domain     npld-2013  2015       crawl-logs     1734755
# 16   npld       domain     npld-2013  2015       logs           1734880
# 17   npld       domain     npld-2013  2015       logs           1734818
# 18   npld       domain     npld-2013  2015       viral          1917301
# 19   npld       domain     npld-2013  2015       viral          1917420
# 20   npld       domain     npld-2013  2015       warcs          2097790
# 21   npld       domain     npld-2013  2015       warcs          2162185
# 22   npld       domain     npld-2013  2016       crawl-logs     1798493
# 23   npld       domain     npld-2013  2016       crawl-logs     1795833
# 24   npld       domain     npld-2013  2016       logs           1797444
# 25   npld       domain     npld-2013  2016       logs           1797008
# 26   npld       domain     npld-2013  2016       viral          1917464
# 27   npld       domain     npld-2013  2016       viral          1917188
# 28   npld       domain     npld-2013  2016       warcs          2186126
# 29   npld       domain     npld-2013  2016       warcs          2243578
# 30   npld       domain     npld-2013  2017       crawl-logs     1799045
# 31   npld       domain     npld-2013  2017       crawl-logs     1796435
# 32   npld       domain     npld-2013  2017       logs           1796484
# 33   npld       domain     npld-2013  2017       logs           1796367
# 34   npld       domain     npld-2013  2017       viral          1917374
# 35   npld       domain     npld-2013  2017       viral          1917232
# 36   npld       domain     npld-2013  2017       warcs          2331822
# 37   npld       domain     npld-2013  2017       warcs          2148919
# 38   npld       domain     npld-2018  2018       crawl-logs     1652424
# 39   npld       domain     npld-2018  2018       crawl-logs     1674656
# 40   npld       domain     npld-2018  2018       viral          1669258
# 41   npld       domain     npld-2018  2018       viral          1661952
# 42   npld       domain     npld-2018  2018       warcs          1678183
# 43   npld       domain     npld-2018  2018       warcs          1679431
# 44   npld       domain     npld-2018  2019       crawl-logs     1626904
# 45   npld       domain     npld-2018  2019       crawl-logs     1629793
# 46   npld       domain     npld-2018  2019       viral          1638932
# 47   npld       domain     npld-2018  2019       viral          1690399
# 48   npld       domain     npld-2018  2019       warcs          1700009
# 49   npld       domain     npld-2018  2019       warcs          1695703
# 50   npld       frequent   npld-2013  2013       logs           1785838
# 51   npld       frequent   npld-2013  2013       logs           1777741
# 52   npld       frequent   npld-2013  2013       viral          1917550
# 53   npld       frequent   npld-2013  2013       viral          1917686
# 54   npld       frequent   npld-2013  2013       warcs          2375573
# 55   npld       frequent   npld-2013  2013       warcs          2377585
# 56   npld       frequent   npld-2013  2014       logs           1902532
# 57   npld       frequent   npld-2013  2014       logs           1779953
# 58   npld       frequent   npld-2013  2014       viral          1917751
# 59   npld       frequent   npld-2013  2014       viral          1917841
# 60   npld       frequent   npld-2013  2014       warcs          2478829
# 61   npld       frequent   npld-2013  2014       warcs          2375429
# 62   npld       frequent   npld-2013  2015       logs           1785401
# 63   npld       frequent   npld-2013  2015       logs           1736796
# 64   npld       frequent   npld-2013  2015       viral          1917693
# 65   npld       frequent   npld-2013  2015       viral          1917762
# 66   npld       frequent   npld-2013  2015       warcs          2483347
# 67   npld       frequent   npld-2013  2015       warcs          1921795
# 68   npld       frequent   npld-2013  2016       crawl-logs     1727389
# 69   npld       frequent   npld-2013  2016       crawl-logs     1801592
# 70   npld       frequent   npld-2013  2016       logs           1873320
# 71   npld       frequent   npld-2013  2016       logs           1738406
# 72   npld       frequent   npld-2013  2016       viral          1917900
# 73   npld       frequent   npld-2013  2016       viral          1917896
# 74   npld       frequent   npld-2013  2016       warcs          2429047
# 75   npld       frequent   npld-2013  2016       warcs          2021267
# 76   npld       frequent   npld-2013  2017       crawl-logs     1785503
# 77   npld       frequent   npld-2013  2017       crawl-logs     1731848
# 78   npld       frequent   npld-2013  2017       logs           1808426
# 79   npld       frequent   npld-2013  2017       logs           1810769
# 80   npld       frequent   npld-2013  2017       viral          1917966
# 81   npld       frequent   npld-2013  2017       viral          1917950
# 82   npld       frequent   npld-2013  2017       warcs          2357595
# 83   npld       frequent   npld-2013  2017       warcs          2029698
# 84   npld       frequent   npld-2013  2017       warcs-invalid  2031496
# 85   npld       frequent   npld-2013  2017       warcs-invalid  2023531
# 86   npld       frequent   npld-2013  2018       crawl-logs     1763600
# 87   npld       frequent   npld-2013  2018       crawl-logs     1812674
# 88   npld       frequent   npld-2013  2018       logs           1762481
# 89   npld       frequent   npld-2013  2018       logs           1888604
# 90   npld       frequent   npld-2013  2018       viral          1918162
# 91   npld       frequent   npld-2013  2018       viral          1917641
# 92   npld       frequent   npld-2013  2018       warcs          2365627
# 93   npld       frequent   npld-2013  2018       warcs          2443842
# 94   npld       frequent   npld-2013  2018       warcs-invalid  2355919
# 95   npld       frequent   npld-2013  2018       warcs-invalid  2040472
# 96   npld       frequent   npld-2013  2019       crawl-logs     1899010
# 97   npld       frequent   npld-2013  2019       crawl-logs     1822513
# 98   npld       frequent   npld-2013  2019       logs           1769649
# 99   npld       frequent   npld-2013  2019       logs           1764335
# 100  npld       frequent   npld-2013  2019       viral          1918329
# 101  npld       frequent   npld-2013  2019       viral          1916937
# 102  npld       frequent   npld-2013  2019       warcs          2077456
# 103  npld       frequent   npld-2013  2019       warcs          2080730
# 104  npld       frequent   npld-2018  2018       warcs          1701693
# 105  npld       frequent   npld-2018  2018       warcs          1703278
# 106  npld       frequent   npld-2018  2019       crawl-logs     1703692
# 107  npld       frequent   npld-2018  2019       crawl-logs     1706672
# 108  npld       frequent   npld-2018  2019       logs           1709285
# 109  npld       frequent   npld-2018  2019       logs           1708576
# 110  npld       frequent   npld-2018  2019       viral          1714157
# 111  npld       frequent   npld-2018  2019       viral          1714167
# 112  npld       frequent   npld-2018  2019       warcs          1704126
# 113  npld       frequent   npld-2018  2019       warcs          1707428
# 114  selective  selective  wct        2010       crawl-logs     675823
# 115  selective  selective  wct        2010       crawl-logs     1235203
# 116  selective  selective  wct        2010       dlx            655544
# 117  selective  selective  wct        2010       dlx            656027
# 118  selective  selective  wct        2010       logs           1209519
# 119  selective  selective  wct        2010       logs           1254339
# 120  selective  selective  wct        2010       unknown        712053
# 121  selective  selective  wct        2010       unknown        786113
# 122  selective  selective  wct        2010       warcs          710226
# 123  selective  selective  wct        2010       warcs          719415
# 124  selective  selective  wct        2011       crawl-logs     1084067
# 125  selective  selective  wct        2011       crawl-logs     1406571
# 126  selective  selective  wct        2011       dlx            1558135
# 127  selective  selective  wct        2011       dlx            747449
# 128  selective  selective  wct        2011       logs           743394
# 129  selective  selective  wct        2011       logs           1253246
# 130  selective  selective  wct        2011       unknown        774147
# 131  selective  selective  wct        2011       unknown        1235225
# 132  selective  selective  wct        2011       warcs          811871
# 133  selective  selective  wct        2011       warcs          933695
# 134  selective  selective  wct        2011       warcs-invalid  1619849
# 135  selective  selective  wct        2011       warcs-invalid  955662
# 136  selective  selective  wct        2012       cdx            808561
# 137  selective  selective  wct        2012       cdx            1362229
# 138  selective  selective  wct        2012       crawl-logs     1592610
# 139  selective  selective  wct        2012       crawl-logs     1499972
# 140  selective  selective  wct        2012       dlx            872410
# 141  selective  selective  wct        2012       dlx            669563
# 142  selective  selective  wct        2012       logs           1426399
# 143  selective  selective  wct        2012       logs           706240
# 144  selective  selective  wct        2012       unknown        988673
# 145  selective  selective  wct        2012       unknown        1394344
# 146  selective  selective  wct        2012       warcs          1493134
# 147  selective  selective  wct        2012       warcs          712200
# 148  selective  selective  wct        2013       cdx            1431918
# 149  selective  selective  wct        2013       cdx            1438333
# 150  selective  selective  wct        2013       crawl-logs     1322790
# 151  selective  selective  wct        2013       crawl-logs     888758
# 152  selective  selective  wct        2013       dlx            1285207
# 153  selective  selective  wct        2013       dlx            1589205
# 154  selective  selective  wct        2013       logs           1344427
# 155  selective  selective  wct        2013       logs           767214
# 156  selective  selective  wct        2013       unknown        1617887
# 157  selective  selective  wct        2013       unknown        738572
# 158  selective  selective  wct        2013       warcs          743980
# 159  selective  selective  wct        2013       warcs          1402931
# 160  selective  selective  wct        2014       cdx            1275204
# 161  selective  selective  wct        2014       cdx            1449361
# 162  selective  selective  wct        2014       crawl-logs     993138
# 163  selective  selective  wct        2014       crawl-logs     1020505
# 164  selective  selective  wct        2014       dlx            729825
# 165  selective  selective  wct        2014       dlx            858248
# 166  selective  selective  wct        2014       logs           1061163
# 167  selective  selective  wct        2014       logs           1356221
# 168  selective  selective  wct        2014       unknown        1264800
# 169  selective  selective  wct        2014       unknown        975867
# 170  selective  selective  wct        2014       warcs          728328
# 171  selective  selective  wct        2014       warcs          1398228
# 172  selective  selective  wct        2015       cdx            717804
# 173  selective  selective  wct        2015       cdx            1013256
# 174  selective  selective  wct        2015       crawl-logs     1127262
# 175  selective  selective  wct        2015       crawl-logs     1062045
# 176  selective  selective  wct        2015       dlx            687843
# 177  selective  selective  wct        2015       dlx            1095845
# 178  selective  selective  wct        2015       logs           1298258
# 179  selective  selective  wct        2015       logs           625230
# 180  selective  selective  wct        2015       unknown        1023409
# 181  selective  selective  wct        2015       unknown        675195
# 182  selective  selective  wct        2015       warcs          1485112
# 183  selective  selective  wct        2015       warcs          1127752
# 184  selective  selective  wct        2016       cdx            1459114
# 185  selective  selective  wct        2016       cdx            1383158
# 186  selective  selective  wct        2016       crawl-logs     1128574
# 187  selective  selective  wct        2016       crawl-logs     660181
# 188  selective  selective  wct        2016       dlx            1183721
# 189  selective  selective  wct        2016       dlx            1427357
# 190  selective  selective  wct        2016       logs           1109147
# 191  selective  selective  wct        2016       logs           969976
# 192  selective  selective  wct        2016       unknown        1052121
# 193  selective  selective  wct        2016       unknown        1108508
# 194  selective  selective  wct        2016       warcs          1123288
# 195  selective  selective  wct        2016       warcs          1206277
# 196  selective  selective  wct        2017       unknown        1620462
# 197  selective  selective  wct        2017       unknown        1620462
# 198  selective  selective  wct        2019       unknown        1623346
# 199  selective  selective  wct        2019       unknown        1623345
#
#                                                                                                                              file_path
# 0    /heritrix/output/logs/crawl0-20130412144423/crawl.log
# 1    /heritrix/output/logs/crawl0-20130412144423/crawl.log.20130423110643
# 2    /heritrix/output/logs/crawl2-20130412144921/crawl2-20130412144921.zip
# 3    /heritrix/output/logs/crawl2-20130412144921/crawl2-20130412144921.zip
# 4    /heritrix/output/viral/crawl0-20130412144423/BL-20130412160848476-00000-23518~crawler02~8443.warc.gz
# 5    /heritrix/output/viral/crawl3-20130412145049/BL-20130610215522877-00000-8769~crawler02~8446.warc.gz
# 6    /heritrix/output/warcs/crawl0-20130412144423/BL-20130413005409078-00070-23518~crawler02~8443.warc.gz
# 7    /heritrix/output/warcs/crawl1-20130412144637/BL-20130416121014319-00950-23604~crawler02~8444.warc.gz
# 8    /heritrix/output/logs/crawl1-20140610125808/scope.log.cp00004-20140621021729.gz
# 9    /heritrix/output/logs/crawl2-20140610125818/scope.log.cp00030-20141208141541.gz
# 10   /heritrix/output/viral/crawl0-20140610125756/BL-20140619104015341-00000-20200~crawler02~8443.warc.gz
# 11   /heritrix/output/viral/crawl0-20140610125756/BL-20140717185921388-00011-18714~crawler02~8443.warc.gz
# 12   /heritrix/output/warcs/crawl1-20140610125808/BL-20141102133654255-04160-31233~crawler02~8444.warc.gz
# 13   /heritrix/output/warcs/crawl3-20140610125825/BL-20141122131917845-05360-22151~crawler02~8446.warc.gz
# 14   /heritrix/output/logs/crawl1-20140610125808/crawl.log.cp00001-20140614073729.gz
# 15   /heritrix/output/logs/crawl0-20140610125756/crawl.log.cp00009-20140625114545.gz
# 16   /heritrix/output/logs/crawl2-20140610125818/scope.log.cp00039-20141223201541.gz
# 17   /heritrix/output/logs/crawl1-20140610125808/crawl1-20140610125808.zip
# 18   /heritrix/output/viral/dc2-20150827/BL-20151129065729776-00035-15367~crawler04~8445.warc.gz
# 19   /heritrix/output/viral/dc3-20150827/BL-20151007070248549-00020-23974~crawler04~8446.warc.gz
# 20   /heritrix/output/warcs/dc0-20150827/BL-20150921213011879-00399-23812~crawler04~8443.warc.gz
# 21   /heritrix/output/warcs/dc1-20150827/BL-20150923054401109-04822-22754~crawler04~8444.warc.gz
# 22   /heritrix/output/logs/dc3-20160810/crawl.log.cp00034-20161022070133
# 23   /heritrix/output/logs/dc1-20160810/crawl.log.20160819152338
# 24   /heritrix/output/logs/dc2-20160810/runtime-errors.log.cp00012-20160907064807
# 25   /heritrix/output/logs/dc2-20150827/uri-errors.log.cp00038-20151130111323.gz
# 26   /heritrix/output/viral/dc3-20160810/BL-20160918010328733-00012-962~crawler04~8446.warc.gz
# 27   /heritrix/output/viral/dc1-20160810/BL-20161001082128885-00020-13423~crawler04~8444.warc.gz
# 28   /heritrix/output/warcs/dc1-20160810/BL-20161029023900985-10253-3777~crawler04~8444.warc.gz
# 29   /heritrix/output/warcs/dc2-20160810/BL-20160903194829584-01912-875~crawler04~8445.warc.gz
# 30   /heritrix/output/logs/dc3-20170515/crawl.log.cp00032-20170813233513
# 31   /heritrix/output/logs/dc1-20170515/crawl.log.cp00033-20170805121238
# 32   /heritrix/output/logs/dc1-20170515/frontier.recover.gz.cp00017-20170707090442
# 33   /heritrix/output/logs/dc1-20170515/alerts.log.cp00030-20170726140950
# 34   /heritrix/output/viral/dc2-20170515/BL-20170615083028728-00004-3882~crawler04.bl.uk~8445.warc.gz
# 35   /heritrix/output/viral/dc1-20170515/BL-20170613212947984-00003-3801~crawler04.bl.uk~8444.warc.gz
# 36   /heritrix/output/warcs/dc3-20170515/BL-20170618061835929-04493-3963~crawler04.bl.uk~8446.warc.gz
# 37   /heritrix/output/warcs/dc0-20170515/BL-20170720190650146-11701-28919~crawler04.bl.uk~8443.warc.gz
# 38   /heritrix/output/dc2018/20180911145815-h3-2/logs/crawl.log.cp00006-20180917145849
# 39   /heritrix/output/dc2018/20181015150657-h3-12/logs/crawl.log.cp00065-20181201150755
# 40   /heritrix/output/dc2018/20180919103936-h3-13/viral/BL-VIRAL-20180924033631626-00000-6848~h3-13~8443.warc.gz
# 41   /heritrix/output/dc2018/20180919103935-h3-15/viral/BL-VIRAL-20180930045514545-00003-6848~h3-15~8443.warc.gz
# 42   /heritrix/output/dc2018/20181015150657-h3-4/warcs/BL-20181230152527406-02315-15398~h3-4~8443.warc.gz
# 43   /heritrix/output/dc2018/20181015150657-h3-8/warcs/BL-20181020182619019-01514-15399~h3-8~8443.warc.gz
# 44   /heritrix/output/dc2018/20180709121757-ecc5b8443dc0/logs/crawl.log
# 45   /heritrix/output/dc2018/20180715072213-e8f0bc0a1c98/logs/crawl.log
# 46   /heritrix/output/dc2018/20180724221454-h3-11/viral/BL-VIRAL-20180801064637821-00002-11362~h3-11~8443.warc.gz
# 47   /heritrix/output/dc2019/20190621113038/viral/BL-NPLD-VIRAL-20190626011907919-00006-71~npld-dc-heritrix3-worker-1~8443.warc.gz
# 48   /heritrix/output/dc2019/20190703144442/warcs/BL-NPLD-20190710105026161-09654-71~npld-dc-heritrix3-worker-1~8443.warc.gz
# 49   /heritrix/output/dc2019/20190621113038/warcs/BL-NPLD-20190628063622834-06235-71~npld-dc-heritrix3-worker-1~8443.warc.gz
# 50   /heritrix/output/logs/daily-1300-20130604130033/daily-1300-20130604130033.zip
# 51   /heritrix/output/logs/daily-0600-20130608060041/daily-0600-20130608060041.zip
# 52   /heritrix/output/viral/latest-20130809093642/20131204101334/BL-20131218132014652-00000-9847~opera~8443.warc.gz
# 53   /heritrix/output/viral/monthly-081200/20130808110016/BL-20130808111415331-00000-25361~opera~8443.warc.gz
# 54   /heritrix/output/warcs/monthly-081300/20130808120104/BL-20130812050501499-00021-25361~opera~8443.warc.gz
# 55   /heritrix/output/warcs/nhs-focussed-201304081406/BL-20130413054755138-00658-12266~opera~8445.warc.gz
# 56   /heritrix/output/logs/weekly-fri0900/20131220161223/20131220161223.zip
# 57   /heritrix/output/logs/daily-0900/20140816080123/20140816080123.zip
# 58   /heritrix/output/viral/quarterly-1-240200/20141024011206/BL-20141103004334827-00000-26811~opera~8443.warc.gz
# 59   /heritrix/output/viral/sixmonthly-2-051000/20140205100045/BL-20140208022358949-00001-6860~opera~8443.warc.gz
# 60   /heritrix/output/warcs/weekly-fri0900/20140110090216/BL-20140110183149558-00039-26191~opera~8443.warc.gz
# 61   /heritrix/output/warcs/monthly-081200/20140610090651/BL-20140623223101813-00054-17066~opera~8446.warc.gz
# 62   /heritrix/output/logs/daily-1300/20150208132515/20150208132515.zip
# 63   /heritrix/output/logs/daily/20151203120419/20151203120419.zip
# 64   /heritrix/output/viral/quarterly/20151001111111/BL-20151006071545030-00001-4727~crawler03~8443.warc.gz
# 65   /heritrix/output/viral/sixmonthly/20150611153324/BL-20150612072752937-00001-4727~crawler03~8443.warc.gz
# 66   /heritrix/output/warcs/weekly-sat0000/20150328001411/BL-20150328001603248-00004-2318~crawler03~8445.warc.gz
# 67   /heritrix/output/warcs/annual-03130300/20150313030248/BL-20150326170154831-00033-31982~crawler03~8443.warc.gz
# 68   /heritrix/output/logs/annual/20161020161712/crawl.log.cp00002-20161024013728
# 69   /heritrix/output/logs/monthly/20161001110557/crawl.log.cp00009-20161016170654
# 70   /heritrix/output/logs/weekly/20160222173716/20160222173716.zip
# 71   /heritrix/output/logs/daily/20160713110132/20160713110132.zip
# 72   /heritrix/output/viral/weekly/20160919110823/BL-20160922043841714-00001-11562~194.66.232.91~8445.warc.gz
# 73   /heritrix/output/viral/weekly/20160905110659/BL-20160905152120707-00000-11562~194.66.232.91~8445.warc.gz
# 74   /heritrix/output/warcs/weekly/20161205120947/BL-20161205181553627-00037-9170~crawler03.bl.uk~8445.warc.gz
# 75   /heritrix/output/warcs/daily/20160112120717/BL-20160112120735138-00002-13366~crawler03~8444.warc.gz
# 76   /heritrix/output/logs/daily-1300/20150223132523/crawl.log.gz
# 77   /heritrix/output/logs/annual-03130300/20150313030248/crawl.log.cp00003-20150318050248.gz
# 78   /heritrix/output/logs/monthly/20170801050113/uri-errors.log.cp00040-20170811050126.sha512
# 79   /heritrix/output/logs/monthly/20171101060126/frontier.recover.gz.cp00108-20171128060140
# 80   /heritrix/output/viral/weekly/20170606080322/BL-VIRAL-20170609142340018-00003-63~ukwa-h3-pulse-weekly~8443.warc.gz
# 81   /heritrix/output/viral/weekly/20170515070124/BL-VIRAL-20170515130547090-00001-63~ukwa-h3-pulse-weekly~8443.warc.gz
# 82   /heritrix/output/warcs/monthly/20171001050128/BL-20171001122420671-00022-62~ukwa-h3-pulse-monthly~8443.warc.gz
# 83   /heritrix/output/warcs/daily/20170202120135/BL-20170202120241180-00006-23888~crawler03~8444.warc.gz
# 84   /heritrix/output/warcs/daily/20170321120037/BL-20170321140012807-00009-63~ukwa-h3-pulse-daily~8443.warc.gz.open
# 85   /heritrix/output/warcs/daily/20160424110832/BL-20160424182421413-00018-31407~crawler03~8444.warc.gz.invalid
# 86   /heritrix/output/logs/daily/20181219120652/crawl.log.cp00002-20181220000700
# 87   /heritrix/output/logs/monthly/20180201060039/crawl.log.cp00054-20180214180040
# 88   /heritrix/output/logs/daily/20181116120412/runtime-errors.log
# 89   /heritrix/output/logs/weekly/20180529130925/nonfatal-errors.log.cp00010-20180601010936
# 90   /heritrix/output/viral/weekly/20180625080108/BL-VIRAL-20180626002751851-00001-63~ukwa-h3-pulse-weekly~8443.warc.gz
# 91   /heritrix/output/viral/monthly/20180808150927/BL-VIRAL-20180808211419677-00001-63~ukwa-h3-pulse-monthly~8443.warc.gz
# 92   /heritrix/output/warcs/monthly/20180808150927/BL-20180830151000434-01437-63~ukwa-h3-pulse-monthly~8443.warc.gz
# 93   /heritrix/output/warcs/weekly/20180219090041/BL-20180219105430553-00014-62~ukwa-h3-pulse-weekly~8443.warc.gz
# 94   /heritrix/output/warcs/monthly/20170601040110/BL-20170629040219076-00254-63~ukwa-h3-pulse-monthly~8443.warc.gz.open
# 95   /heritrix/output/warcs/daily/20171003114716/BL-20171003234748660-00014-63~ukwa-h3-pulse-daily~8443.warc.gz.open
# 96   /heritrix/output/logs/weekly/20190617080234/crawl.log
# 97   /heritrix/output/logs/monthly/20190601130308/crawl.log.cp00011-20190604070702
# 98   /heritrix/output/logs/daily/20190623110227/nonfatal-errors.log.cp00003-20190624050242
# 99   /heritrix/output/logs/daily/20190110120732/nonfatal-errors.log.cp00005-20190111120738
# 100  /heritrix/output/viral/weekly/20190422080334/BL-VIRAL-20190422222501700-00000-63~ukwa-h3-pulse-weekly~8443.warc.gz
# 101  /heritrix/output/viral/daily/20190630110157/BL-VIRAL-20190630215159205-00001-63~ukwa-h3-pulse-daily~8443.warc.gz
# 102  /heritrix/output/warcs/daily/20190418110210/BL-20190419100757469-00059-63~ukwa-h3-pulse-daily~8443.warc.gz
# 103  /heritrix/output/warcs/daily/20190518110210/WREN-daily-20190518110210-20190518-20190518130225803-00013-dm8h7qo1.warc.gz
# 104  /heritrix/output/frequent/20180917085005-84904b73b855/warcs/BL-20181001085031581-00789-6849~84904b73b855~8443.warc.gz
# 105  /heritrix/output/frequent/20181108095851-edf339eeaf76/warcs/BL-20181121025410392-01279-15400~edf339eeaf76~8443.warc.gz
# 106  /heritrix/output/frequent/20181213142528-edf339eeaf76/logs/crawl.log.cp00087-20181231142730
# 107  /heritrix/output/frequent/20190307163413/logs/crawl.log
# 108  /heritrix/output/frequent/20190329225505/logs/wp.log
# 109  /heritrix/output/frequent/20190326113906/logs/h3.log
# 110  /heritrix/output/frequent-npld/20190517145608/viral/BL-NPLD-VIRAL-20190601110439041-00017-75~npld-heritrix3-worker-1~8443.warc.gz
# 111  /heritrix/output/frequent-npld/20190517145608/viral/BL-NPLD-VIRAL-20190611110422394-00027-75~npld-heritrix3-worker-1~8443.warc.gz
# 112  /heritrix/output/frequent/20181213142528-edf339eeaf76/warcs/BL-20190114100415939-02085-15399~edf339eeaf76~8443.warc.gz
# 113  /heritrix/output/frequent/20190314163655/warcs/BL-NPLD-20190315103827314-00328-14873~heritrix3-worker-1~8443.warc.gz
# 114  /data/105290/38502676/Logs/crawl.log
# 115  /data/39714832/55346387/Logs/crawl.log
# 116  /data/102223/102231/DLX/BL-102231-0.warc.dlx
# 117  /data/102308/102320/DLX/BL-102320-0.warc.dlx
# 118  /data/34406414/34799623/Logs/uri-errors.log
# 119  /data/43188258/44269594/Logs/uri-errors.log
# 120  /data/112612/112624/METS.xml
# 121  /data/121065/121073/METS.xml
# 122  /data/111834/111845/WARCS/BL-111845-0.warc.gz
# 123  /data/113954/113964/WARCS/BL-113964-0.warc.gz
# 124  /data/27099198/27197856/Logs/crawl.log
# 125  /data/60588609/60817758/Logs/crawl.log
# 126  /data/8486916/31065993/DLX/BL-31065993-37.warc.dlx
# 127  /data/11534365/31064335/DLX/BL-31064335-3.warc.dlx
# 128  /data/11534342/58819131/Logs/local-errors.log
# 129  /data/42532864/55346404/Logs/uri-errors.log
# 130  /data/118588/57639363/order.xml
# 131  /data/39714834/39616635/order.xml
# 132  /data/124421/31851269/WARCS/BL-31851269-1.warc.gz
# 133  /data/14254081/13991961/WARCS/BL-13991961-0.warc.gz
# 134  /data/99719/8945686/WARCS/BL-89456.swp
# 135  /data/15237189/14975047/WARCS/BL-14975047-2.warc.dlx
# 136  /data/123847/64357089/WARCS/BL-64357089-20120612220052-00000-safari.bl.uk.warc.cdx
# 137  /data/60293156/65180314/WARCS/BL-65180314-20120823000048-00000-safari.bl.uk.warc.cdx
# 138  /data/9175096/60393593/Logs/crawl.log
# 139  /data/65994797/65733280/Logs/crawl.log
# 140  /data/132636/62194378/DLX/BL-62194378-20120119230044-00000-safari.bl.uk.warc.dlx
# 141  /data/103946/61309045/DLX/BL-61309045-20111206231314-00001-safari.bl.uk.warc.dlx
# 142  /data/62521381/63244586/Logs/uri-errors.log
# 143  /data/111170/65176994/Logs/local-errors.log
# 144  /data/20480003/63964998/order.xml
# 145  /data/60588269/62193845/METS.xml
# 146  /data/65208852/65182446/WARCS/BL-65182446-20120801231050-00000-safari.bl.uk.warc.gz
# 147  /data/112612/65177757/WARCS/BL-65177757-20120802220019-00000-safari.bl.uk.warc.gz
# 148  /data/63275049/190480725/WARCS/BL-190480725-20131212024931-00003-safari.bl.uk.warc.cdx
# 149  /data/63275121/190481246/WARCS/BL-190481246-20131009152134-00009-safari.bl.uk.warc.cdx
# 150  /data/57114647/66129328/Logs/crawl.log
# 151  /data/136019985/135694133/Logs/crawl.log
# 152  /data/49315941/65178113/DLX/BL-65178113-20120810092322-00019-safari.bl.uk.warc.dlx
# 153  /data/9175051/66130082/DLX/BL-66130082-20130123060322-00023-safari.bl.uk.warc.dlx
# 154  /data/59113593/72090040/Logs/uri-errors.log
# 155  /data/117342247/130220070/Logs/uri-errors.log
# 156  /data/99340/65181683/METS.xml
# 157  /data/11534340/116293633/order.xml
# 158  /data/11534342/79659580/WARCS/BL-79659580-20130305073456-00003-safari.bl.uk.warc.gz
# 159  /data/60588561/92897660/WARCS/BL-92897660-20130325164845-00002-safari.bl.uk.warc.gz
# 160  /data/48791604/236095188/WARCS/BL-236095188-20140826095020-00003-safari.bl.uk.warc.cdx
# 161  /data/64290914/260702614/WARCS/BL-260702614-20141118100322-00004-safari.bl.uk.warc.cdx
# 162  /data/218955816/236094881/Logs/crawl.log
# 163  /data/235438241/260702478/Logs/crawl.log
# 164  /data/11534337/203424597/DLX/BL-203424597-20131227115316-00589-safari.bl.uk.warc.dlx
# 165  /data/130941/190481542/DLX/BL-190481542-20140116231242-00001-safari.bl.uk.warc.dlx
# 166  /data/266338337/277152312/Logs/uri-errors.log
# 167  /data/59703297/260702377/Logs/local-errors.log
# 168  /data/4620289/190481099/order.xml
# 169  /data/182124550/203423844/order.xml
# 170  /data/11534337/203423914/WARCS/BL-203423914-20140208132351-00365-safari.bl.uk.warc.gz
# 171  /data/60588446/265880254/WARCS/BL-265880254-20141009121408-00022-safari.bl.uk.warc.gz
# 172  /data/113726/324567396/WARCS/BL-324567396-20151112085007-00113-safari.bl.uk.warc.cdx
# 173  /data/235438215/293670400/WARCS/BL-293670400-20150809043949-00009-safari.bl.uk.warc.cdx
# 174  /data/293863756/324568205/Logs/crawl.log
# 175  /data/266338337/293669191/Logs/crawl.log
# 176  /data/106872/321814805/DLX/BL-321814805-20151001102754-00003-safari.bl.uk.warc.dlx
# 177  /data/277413927/293667905/DLX/BL-293667905-20150529111014-00029-safari.bl.uk.warc.dlx
# 178  /data/49905700/324567419/Logs/uri-errors.log
# 179  /data/102036/293668809/Logs/runtime-errors.log
# 180  /data/235438241/293670565/order.xml
# 181  /data/105092/292651055/order.xml
# 182  /data/65208676/293667337/WARCS/BL-293667337-20150517081331-00003-safari.bl.uk.warc.gz
# 183  /data/293863790/324568245/WARCS/BL-324568245-20151215030639-00006-safari.bl.uk.warc.gz
# 184  /data/64454694/339378857/WARCS/BL-339378857-20160130230024-00000-safari.bl.uk.warc.cdx
# 185  /data/60293371/339378661/WARCS/BL-339378661-20160124230836-00003-safari.bl.uk.warc.cdx
# 186  /data/293863815/324568519/Logs/crawl.log
# 187  /data/102621/324568639/Logs/crawl.log
# 188  /data/326434834/339379435/DLX/BL-339379435-20160219012304-00000-safari.bl.uk.warc.dlx
# 189  /data/62521392/339379341/DLX/BL-339379341-20160216010206-00001-safari.bl.uk.warc.dlx
# 190  /data/286294061/339378365/Logs/uri-errors.log
# 191  /data/172294169/324568886/Logs/uri-errors.log
# 192  /data/261128196/339379480/METS.xml
# 193  /data/286294027/324568841/METS.xml
# 194  /data/293863570/339380346/WARCS/BL-339380346-20151219021132-00006-safari.bl.uk.warc.gz
# 195  /data/339312695/339380722/WARCS/BL-339380722-20160201124104-00000-safari.bl.uk.warc.gz
# 196  /data/prod/heritrix/output/logs/daily/20170702114807/alerts.log.cp00002-20170702234832
# 197  /data/prod/heritrix/output/logs/daily/20170702114807/alerts.log.cp00002-20170702234832
# 198  /data/videos/firefox-var_www.tar.gz
# 199  /data/videos/firefox-opt_red5.tar.gz

# %% [markdown]
# Timestamp Checks
# ----------------------------
#
# Processing the data downstream, we came across this event.
#
#    duplicate key value (filename,job_name,job_launch)=('crawl.log','dc2019','20190524') violates unique constraint "primary"
#
# For more recent crawls, the fine-grained timestamp should not be that short a string.

# %%
df.loc[df['job'] == 'dc2019'].head()
# Out:
#          recognised collection  stream     job     layout        kind  \
# 1689117  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689118  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689119  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689120  True        npld       domain  dc2019  npld-2018  crawl-logs
# 1689121  True        npld       domain  dc2019  npld-2018  crawl-logs
#
#         permissions  number_of_replicas user_id    group_id  file_size  \
# 1689117  -rw-r--r--  3                   hdfs    supergroup  0
# 1689118  -rw-r--r--  3                   hdfs    supergroup  0
# 1689119  -rw-r--r--  3                   hdfs    supergroup  860
# 1689120  -rw-r--r--  3                   hdfs    supergroup  0
# 1689121  -rw-r--r--  3                   hdfs    supergroup  0
#
#                  modified_at           timestamp  \
# 1689117  2019-06-19T11:35:00 2019-06-19 11:35:00
# 1689118  2019-06-20T16:44:00 2019-06-20 16:44:00
# 1689119  2019-06-19T11:35:00 2019-06-19 11:35:00
# 1689120  2019-06-20T16:45:00 2019-06-20 16:45:00
# 1689121  2019-06-20T16:45:00 2019-06-20 16:45:00
#
#                                                                             file_path  \
# 1689117  /heritrix/output/dc2019/20190524140702/logs/crawl.log
# 1689118  /heritrix/output/dc2019/20190524140702/logs/crawl.log.cp00001-20190524141211
# 1689119  /heritrix/output/dc2019/20190524141331/logs/crawl.log
# 1689120  /heritrix/output/dc2019/20190524141331/logs/crawl.log.cp00001-20190525141333
# 1689121  /heritrix/output/dc2019/20190524141331/logs/crawl.log.cp00002-20190526141333
#
#                                 file_name                     file_ext
# 1689117  crawl.log                         .log
# 1689118  crawl.log.cp00001-20190524141211  .log.cp00001-20190524141211
# 1689119  crawl.log                         .log
# 1689120  crawl.log.cp00001-20190525141333  .log.cp00001-20190525141333
# 1689121  crawl.log.cp00002-20190526141333  .log.cp00002-20190526141333
